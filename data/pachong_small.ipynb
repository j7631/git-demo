# %%
import pandas as pd
import requests
import os
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from concurrent.futures import ThreadPoolExecutor, as_completed, TimeoutError

class Crawler_google_images:
    # 初始化
    def __init__(self, index, keyword):
        self.keyword = keyword
        self.url = 'https://www.google.com.hk/search?q=' + keyword + '&tbm=isch'
        self.index = index

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        chrome_options.add_argument("--headless")  # 无头模式
        chrome_options.add_argument("--disable-gpu")
        chrome_options.add_argument("--window-size=1920x1080")
        browser = webdriver.Chrome(options=chrome_options)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        browser.get(self.url)
        return browser

    # 下载图片
    def download_images(self, browser, num_images=5):
        picpath = f'./images_/{str(self.index) + "_" + self.keyword.replace(" ", "_")}'
        # 路径不存在时创建一个
        if not os.path.exists(picpath):
            os.makedirs(picpath)
        # 记录下载过的图片地址，避免重复下载
        img_url_dic = []

        count = 0  # 图片序号
        pos = 0

        while count < num_images:
            pos += 500
            # 向下滑动
            js = 'var q=document.documentElement.scrollTop=' + str(pos)
            browser.execute_script(js)
            time.sleep(1)
            # 找到图片
            img_elements = browser.find_elements(By.TAG_NAME, 'img')
            # 遍历抓到的webElement
            for img_element in img_elements:
                if count >= num_images:
                    break
                img_url = img_element.get_attribute('src')
                # 前几个图片的url太长，不是图片的url，先过滤掉，爬后面的
                if isinstance(img_url, str):
                    if len(img_url) <= 200:
                        # 将干扰的google图标筛去
                        if 'images' in img_url:
                            # 判断是否已经爬过，因为每次爬取当前窗口，或许会重复
                            if img_url not in img_url_dic:
                                try:
                                    img_url_dic.append(img_url)
                                    # 下载并保存图片到当前目录下
                                    filename = f"./images_/{str(self.index) + '_' + self.keyword.replace(' ', '_')}/" + str(count) + ".jpg"
                                    r = requests.get(img_url, timeout=10)
                                    with open(filename, 'wb') as f:
                                        f.write(r.content)
                                    count += 1
                                    print(f'This is {count} image for {self.keyword}')
                                    # 防止反爬机制
                                    time.sleep(0.2)
                                except Exception as e:
                                    print(f'Failed to download image {img_url}: {e}')
    
    def run(self, num_images=5):
        try:
            browser = self.init_browser()
            self.download_images(browser, num_images)
        except Exception as e:
            print(f"Error occurred for keyword '{self.keyword}': {e}")
        finally:
            if browser:
                browser.close()
            print(f"Images for {self.keyword} downloaded successfully.")

def download_images_for_subject(index, subject, num_images_to_download, timeout):
    print(f"Downloading images for subject: {subject}")
    crawler = Crawler_google_images(index=index, keyword=subject)
    with ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(crawler.run, num_images=num_images_to_download)
        try:
            future.result(timeout=timeout)
        except TimeoutError:
            print(f"Timeout occurred for subject '{subject}'")
        except Exception as e:
            print(f"Error occurred for subject '{subject}': {e}")

if __name__ == '__main__':
    num_images_to_download = 10  # 每个主题要下载的图片数量
    timeout = 60  # 每个主题下载的超时时间（秒）

    # 从CSV文件中读取数据
    csv_file_path = '/opt/tiger/trl/consistency/git-demo/data/CF-triples_labeled.csv'
    df = pd.read_csv(csv_file_path)
    start_index = 2369
    end_index = 1000
    # 取前1000个subject
    subjects = df['subject'].unique()[start_index:]

    index = start_index
    for subject in subjects:
        try:
            download_images_for_subject(index, subject, num_images_to_download, timeout)
        except Exception as e:
            print(f"Skipping subject '{subject}' due to error: {e}")
        index += 1

    print("All images downloaded successfully.")
# Out:
# Downloading images for subject: Into Thin Air
# This is 1 image for Into Thin Air
# This is 2 image for Into Thin Air
# This is 3 image for Into Thin Air
# This is 4 image for Into Thin Air
# This is 5 image for Into Thin Air
# This is 6 image for Into Thin Air
# This is 7 image for Into Thin Air
# This is 8 image for Into Thin Air
# This is 9 image for Into Thin Air
# This is 10 image for Into Thin Air
# Images for Into Thin Air downloaded successfully.
# Downloading images for subject: Winnipeg Goldeyes
# This is 1 image for Winnipeg Goldeyes
# This is 2 image for Winnipeg Goldeyes
# This is 3 image for Winnipeg Goldeyes
# This is 4 image for Winnipeg Goldeyes
# This is 5 image for Winnipeg Goldeyes
# This is 6 image for Winnipeg Goldeyes
# This is 7 image for Winnipeg Goldeyes
# This is 8 image for Winnipeg Goldeyes
# This is 9 image for Winnipeg Goldeyes
# This is 10 image for Winnipeg Goldeyes
# Images for Winnipeg Goldeyes downloaded successfully.
# Downloading images for subject: Thomas Paine
# This is 1 image for Thomas Paine
# This is 2 image for Thomas Paine
# This is 3 image for Thomas Paine
# This is 4 image for Thomas Paine
# This is 5 image for Thomas Paine
# This is 6 image for Thomas Paine
# This is 7 image for Thomas Paine
# This is 8 image for Thomas Paine
# This is 9 image for Thomas Paine
# This is 10 image for Thomas Paine
# Images for Thomas Paine downloaded successfully.
# Downloading images for subject: Kristiansund BK
# This is 1 image for Kristiansund BK
# This is 2 image for Kristiansund BK
# This is 3 image for Kristiansund BK
# This is 4 image for Kristiansund BK
# This is 5 image for Kristiansund BK
# This is 6 image for Kristiansund BK
# This is 7 image for Kristiansund BK
# This is 8 image for Kristiansund BK
# This is 9 image for Kristiansund BK
# This is 10 image for Kristiansund BK
# Images for Kristiansund BK downloaded successfully.
# Downloading images for subject: Gregory I
# This is 1 image for Gregory I
# This is 2 image for Gregory I
# This is 3 image for Gregory I
# This is 4 image for Gregory I
# This is 5 image for Gregory I
# This is 6 image for Gregory I
# This is 7 image for Gregory I
# This is 8 image for Gregory I
# This is 9 image for Gregory I
# This is 10 image for Gregory I
# Images for Gregory I downloaded successfully.
# Downloading images for subject: William Le Baron Jenney
# This is 1 image for William Le Baron Jenney
# This is 2 image for William Le Baron Jenney
# This is 3 image for William Le Baron Jenney
# This is 4 image for William Le Baron Jenney
# This is 5 image for William Le Baron Jenney
# This is 6 image for William Le Baron Jenney
# This is 7 image for William Le Baron Jenney
# This is 8 image for William Le Baron Jenney
# This is 9 image for William Le Baron Jenney
# This is 10 image for William Le Baron Jenney
# Images for William Le Baron Jenney downloaded successfully.
# Downloading images for subject: Frank R. Strayer
# This is 1 image for Frank R. Strayer
# This is 2 image for Frank R. Strayer
# This is 3 image for Frank R. Strayer
# This is 4 image for Frank R. Strayer
# This is 5 image for Frank R. Strayer
# This is 6 image for Frank R. Strayer
# This is 7 image for Frank R. Strayer
# This is 8 image for Frank R. Strayer
# This is 9 image for Frank R. Strayer
# This is 10 image for Frank R. Strayer
# Images for Frank R. Strayer downloaded successfully.
# Downloading images for subject: Ernest Hemingway
# This is 1 image for Ernest Hemingway
# This is 2 image for Ernest Hemingway
# This is 3 image for Ernest Hemingway
# This is 4 image for Ernest Hemingway
# This is 5 image for Ernest Hemingway
# This is 6 image for Ernest Hemingway
# This is 7 image for Ernest Hemingway
# This is 8 image for Ernest Hemingway
# This is 9 image for Ernest Hemingway
# This is 10 image for Ernest Hemingway
# Images for Ernest Hemingway downloaded successfully.
# Downloading images for subject: Apple TV
# This is 1 image for Apple TV
# This is 2 image for Apple TV
# This is 3 image for Apple TV
# This is 4 image for Apple TV
# This is 5 image for Apple TV
# This is 6 image for Apple TV
# This is 7 image for Apple TV
# This is 8 image for Apple TV
# This is 9 image for Apple TV
# This is 10 image for Apple TV
# Images for Apple TV downloaded successfully.
# Downloading images for subject: Evan McMullin
# This is 1 image for Evan McMullin
# This is 2 image for Evan McMullin
# This is 3 image for Evan McMullin
# This is 4 image for Evan McMullin
# This is 5 image for Evan McMullin
# This is 6 image for Evan McMullin
# This is 7 image for Evan McMullin
# This is 8 image for Evan McMullin
# This is 9 image for Evan McMullin
# This is 10 image for Evan McMullin
# Images for Evan McMullin downloaded successfully.
# Downloading images for subject: Michael Corleone
# This is 1 image for Michael Corleone
# This is 2 image for Michael Corleone
# This is 3 image for Michael Corleone
# This is 4 image for Michael Corleone
# This is 5 image for Michael Corleone
# This is 6 image for Michael Corleone
# This is 7 image for Michael Corleone
# This is 8 image for Michael Corleone
# This is 9 image for Michael Corleone
# This is 10 image for Michael Corleone
# Images for Michael Corleone downloaded successfully.
# Downloading images for subject: Hyacinth of Poland
# This is 1 image for Hyacinth of Poland
# This is 2 image for Hyacinth of Poland
# This is 3 image for Hyacinth of Poland
# This is 4 image for Hyacinth of Poland
# This is 5 image for Hyacinth of Poland
# This is 6 image for Hyacinth of Poland
# This is 7 image for Hyacinth of Poland
# This is 8 image for Hyacinth of Poland
# This is 9 image for Hyacinth of Poland
# This is 10 image for Hyacinth of Poland
# Images for Hyacinth of Poland downloaded successfully.
# Downloading images for subject: Windows Server 2003
# This is 1 image for Windows Server 2003
# This is 2 image for Windows Server 2003
# This is 3 image for Windows Server 2003
# This is 4 image for Windows Server 2003
# This is 5 image for Windows Server 2003
# This is 6 image for Windows Server 2003
# This is 7 image for Windows Server 2003
# This is 8 image for Windows Server 2003
# This is 9 image for Windows Server 2003
# This is 10 image for Windows Server 2003
# Images for Windows Server 2003 downloaded successfully.
# Downloading images for subject: Chris Rock
# This is 1 image for Chris Rock
# This is 2 image for Chris Rock
# This is 3 image for Chris Rock
# This is 4 image for Chris Rock
# This is 5 image for Chris Rock
# This is 6 image for Chris Rock
# This is 7 image for Chris Rock
# This is 8 image for Chris Rock
# This is 9 image for Chris Rock
# This is 10 image for Chris Rock
# Images for Chris Rock downloaded successfully.
# Downloading images for subject: Les Liaisons dangereuses
# This is 1 image for Les Liaisons dangereuses
# This is 2 image for Les Liaisons dangereuses
# This is 3 image for Les Liaisons dangereuses
# This is 4 image for Les Liaisons dangereuses
# This is 5 image for Les Liaisons dangereuses
# This is 6 image for Les Liaisons dangereuses
# This is 7 image for Les Liaisons dangereuses
# This is 8 image for Les Liaisons dangereuses
# This is 9 image for Les Liaisons dangereuses
# This is 10 image for Les Liaisons dangereuses
# Images for Les Liaisons dangereuses downloaded successfully.
# Downloading images for subject: The Famous Five
# This is 1 image for The Famous Five
# This is 2 image for The Famous Five
# This is 3 image for The Famous Five
# This is 4 image for The Famous Five
# This is 5 image for The Famous Five
# This is 6 image for The Famous Five
# This is 7 image for The Famous Five
# This is 8 image for The Famous Five
# This is 9 image for The Famous Five
# This is 10 image for The Famous Five
# Images for The Famous Five downloaded successfully.
# Downloading images for subject: 1993 UNCAF Nations Cup
# This is 1 image for 1993 UNCAF Nations Cup
# This is 2 image for 1993 UNCAF Nations Cup
# This is 3 image for 1993 UNCAF Nations Cup
# This is 4 image for 1993 UNCAF Nations Cup
# This is 5 image for 1993 UNCAF Nations Cup
# This is 6 image for 1993 UNCAF Nations Cup
# This is 7 image for 1993 UNCAF Nations Cup
# This is 8 image for 1993 UNCAF Nations Cup
# This is 9 image for 1993 UNCAF Nations Cup
# Timeout occurred for subject '1993 UNCAF Nations Cup'
# Error occurred for keyword '1993 UNCAF Nations Cup': ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb Cell 1 line 1
#     <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=110'>111</a> for subject in subjects:
#     <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=111'>112</a>     try:
# --> <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=112'>113</a>         download_images_for_subject(index, subject, num_images_to_download, timeout)
#     <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=113'>114</a>     except Exception as e:
#     <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=114'>115</a>         print(f"Skipping subject '{subject}' due to error: {e}")
#
# /opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb Cell 1 line 9
#      <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=93'>94</a>     print(f"Timeout occurred for subject '{subject}'")
#      <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=94'>95</a> except Exception as e:
# ---> <a href='vscode-notebook-cell://icube%2Bicube/opt/tiger/trl/consistency/git-demo/data/pachong_small.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=95'>96</a>     print(f"Error occurred for subject '{subject}': {e}")
#
# File /usr/lib/python3.9/concurrent/futures/_base.py:628, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     627 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 628     self.shutdown(wait=True)
#     629     return False
#
# File /usr/lib/python3.9/concurrent/futures/thread.py:229, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     227 if wait:
#     228     for t in self._threads:
# --> 229         t.join()
#
# File /usr/lib/python3.9/threading.py:1033, in Thread.join(self, timeout)
#    1030     raise RuntimeError("cannot join current thread")
#    1032 if timeout is None:
# -> 1033     self._wait_for_tstate_lock()
#    1034 else:
#    1035     # the behavior of a negative timeout isn't documented, but
#    1036     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1037     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.9/threading.py:1049, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1047 if lock is None:  # already determined that the C code is done
#    1048     assert self._is_stopped
# -> 1049 elif lock.acquire(block, timeout):
#    1050     lock.release()
#    1051     self._stop()
#
# KeyboardInterrupt:

# %%
# date：2020.5.25
# author:pmy
# aim:爬取google图片
#问题在于，不能保证所爬为所见

from selenium import webdriver
import time
import os
import requests

# 修改keyword便可以修改搜索关键词 建议也修改存储目录
keyword = 'cat'
url = 'https://www.google.com.hk/search?q=' + keyword + '&source=lnms&tbm=isch'


class Crawler_google_images:
    # 初始化
    def __init__(self):
        self.url = url

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        browser = webdriver.Chrome(options=chrome_options)
        # 访问url
        browser.get(self.url)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        return browser

    # 下载图片
    def download_images(self, browser, num=5):
        #存储路径
        picpath = './cat'
        # 路径不存在时创建一个
        if not os.path.exists(picpath): os.makedirs(picpath)

        count = 0  # 图片序号
        pos = 0
        # print(num)

        while (True):
            try:
                # 向下滑动
                js = 'var q=document.documentElement.scrollTop=' + str(pos)
                pos += 500
                browser.execute_script(js)
                time.sleep(1)
                # 找到图片
                # html = browser.page_source#也可以抓取当前页面的html文本，然后用beautifulsoup来抓取
                # 直接通过tag_name来抓取是最简单的，比较方便
                img_elements = browser.find_elements_by_xpath('//a[@class="wXeWr islib nfEiy mM5pbd"]')
                try:
                    for img_element in img_elements:
                        #点开大图页面
                        img_element.click()
                        time.sleep(0.5)
                        try:
                            # 这里balabala里面有好几个，所以要过滤一下
                            # 取名好烦哦···
                            balabalas = browser.find_elements_by_xpath('//img[@class="n3VNCb"]')

                            if (balabalas):
                                for balabala in balabalas:
                                    src = balabala.get_attribute('src')
                                    #过滤掉缩略图和无关干扰信息
                                    if src.startswith('http') and not src.startswith(
                                            'https://encrypted-tbn0.gstatic.com'):
                                        print('Found' + str(count) + 'st image url')
                                        # img_url_dic.append(src)
                                        self.save_img(count, src, picpath)
                                        count += 1
                                        #爬取到指定数量图片后退出
                                        if (count >= num):
                                            return "stop"
                        except:
                            print('获取图片失败')

                    #回退
                    browser.back()
                    time.sleep(0.3)
                except:
                    print('获取页面失败')
            except:
                print("划不动了")

    def save_img(self, count, img_src, picpath):
        filename = picpath + '/' + str(count) + '.jpg'
        r = requests.get(img_src)
        with open(filename, 'wb') as f:
            f.write(r.content)
        f.close()

    def run(self):
        self.__init__()
        browser = self.init_browser()
        self.download_images(browser, 100)  # 可以修改爬取的图片数
        browser.close()
        print("############爬取完成")


if __name__ == '__main__':
    craw = Crawler_google_images()
    craw.run()
