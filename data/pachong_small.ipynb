# %%
import pandas as pd
import requests
import os
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from concurrent.futures import ThreadPoolExecutor, as_completed, TimeoutError

class Crawler_google_images:
    # 初始化
    def __init__(self, index, keyword):
        self.keyword = keyword
        self.url = 'https://www.google.com.hk/search?q=' + keyword + '&tbm=isch'
        self.index = index

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        chrome_options.add_argument("--headless")  # 无头模式
        chrome_options.add_argument("--disable-gpu")
        chrome_options.add_argument("--window-size=1920x1080")
        browser = webdriver.Chrome(options=chrome_options)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        browser.get(self.url)
        return browser

    # 下载图片
    def download_images(self, browser, num_images=5):
        picpath = f'./images_/{str(self.index) + "_" + self.keyword.replace(" ", "_")}'
        # 路径不存在时创建一个
        if not os.path.exists(picpath):
            os.makedirs(picpath)
        # 记录下载过的图片地址，避免重复下载
        img_url_dic = []

        count = 0  # 图片序号
        pos = 0

        while count < num_images:
            pos += 500
            # 向下滑动
            js = 'var q=document.documentElement.scrollTop=' + str(pos)
            browser.execute_script(js)
            time.sleep(1)
            # 找到图片
            img_elements = browser.find_elements(By.TAG_NAME, 'img')
            # 遍历抓到的webElement
            for img_element in img_elements:
                if count >= num_images:
                    break
                img_url = img_element.get_attribute('src')
                # 前几个图片的url太长，不是图片的url，先过滤掉，爬后面的
                if isinstance(img_url, str):
                    if len(img_url) <= 200:
                        # 将干扰的google图标筛去
                        if 'images' in img_url:
                            # 判断是否已经爬过，因为每次爬取当前窗口，或许会重复
                            if img_url not in img_url_dic:
                                try:
                                    img_url_dic.append(img_url)
                                    # 下载并保存图片到当前目录下
                                    filename = f"./images_/{str(self.index) + '_' + self.keyword.replace(' ', '_')}/" + str(count) + ".jpg"
                                    r = requests.get(img_url, timeout=10)
                                    with open(filename, 'wb') as f:
                                        f.write(r.content)
                                    count += 1
                                    print(f'This is {count} image for {self.keyword}')
                                    # 防止反爬机制
                                    time.sleep(0.2)
                                except Exception as e:
                                    print(f'Failed to download image {img_url}: {e}')
    
    def run(self, num_images=5):
        try:
            browser = self.init_browser()
            self.download_images(browser, num_images)
        except Exception as e:
            print(f"Error occurred for keyword '{self.keyword}': {e}")
        finally:
            if browser:
                browser.close()
            print(f"Images for {self.keyword} downloaded successfully.")

def download_images_for_subject(index, subject, num_images_to_download, timeout):
    print(f"Downloading images for subject: {subject}")
    crawler = Crawler_google_images(index=index, keyword=subject)
    with ThreadPoolExecutor(max_workers=1) as executor:
        future = executor.submit(crawler.run, num_images=num_images_to_download)
        try:
            future.result(timeout=timeout)
        except TimeoutError:
            print(f"Timeout occurred for subject '{subject}'")
        except Exception as e:
            print(f"Error occurred for subject '{subject}': {e}")

if __name__ == '__main__':
    num_images_to_download = 10  # 每个主题要下载的图片数量
    timeout = 60  # 每个主题下载的超时时间（秒）

    # 从CSV文件中读取数据
    csv_file_path = '/opt/tiger/trl/consistency/git-demo/data/CF-triples_labeled.csv'
    df = pd.read_csv(csv_file_path)
    start_index = 3460
    end_index = 1000
    # 取前1000个subject
    subjects = df['subject'].unique()[start_index:]

    index = start_index
    for subject in subjects:
        try:
            download_images_for_subject(index, subject, num_images_to_download, timeout)
        except Exception as e:
            print(f"Skipping subject '{subject}' due to error: {e}")
        index += 1

    print("All images downloaded successfully.")
# Out:
# Downloading images for subject: G. K. Chesterton
# This is 1 image for G. K. Chesterton
# This is 2 image for G. K. Chesterton
# This is 3 image for G. K. Chesterton
# This is 4 image for G. K. Chesterton
# This is 5 image for G. K. Chesterton
# This is 6 image for G. K. Chesterton
# This is 7 image for G. K. Chesterton
# This is 8 image for G. K. Chesterton
# This is 9 image for G. K. Chesterton
# This is 10 image for G. K. Chesterton
# Images for G. K. Chesterton downloaded successfully.
# Downloading images for subject: Buffalo Bisons
# This is 1 image for Buffalo Bisons
# This is 2 image for Buffalo Bisons
# This is 3 image for Buffalo Bisons
# This is 4 image for Buffalo Bisons
# This is 5 image for Buffalo Bisons
# This is 6 image for Buffalo Bisons
# This is 7 image for Buffalo Bisons
# This is 8 image for Buffalo Bisons
# This is 9 image for Buffalo Bisons
# This is 10 image for Buffalo Bisons
# Images for Buffalo Bisons downloaded successfully.
# Downloading images for subject: Afghanistan
# This is 1 image for Afghanistan
# This is 2 image for Afghanistan
# This is 3 image for Afghanistan
# This is 4 image for Afghanistan
# This is 5 image for Afghanistan
# This is 6 image for Afghanistan
# This is 7 image for Afghanistan
# This is 8 image for Afghanistan
# This is 9 image for Afghanistan
# This is 10 image for Afghanistan
# Images for Afghanistan downloaded successfully.
# Downloading images for subject: Greg Oden
# This is 1 image for Greg Oden
# This is 2 image for Greg Oden
# This is 3 image for Greg Oden
# This is 4 image for Greg Oden
# This is 5 image for Greg Oden
# This is 6 image for Greg Oden
# This is 7 image for Greg Oden
# This is 8 image for Greg Oden
# This is 9 image for Greg Oden
# This is 10 image for Greg Oden
# Images for Greg Oden downloaded successfully.
# Downloading images for subject: 2013–14 A-League
# This is 1 image for 2013–14 A-League
# This is 2 image for 2013–14 A-League
# This is 3 image for 2013–14 A-League
# This is 4 image for 2013–14 A-League
# This is 5 image for 2013–14 A-League
# This is 6 image for 2013–14 A-League
# This is 7 image for 2013–14 A-League
# This is 8 image for 2013–14 A-League
# This is 9 image for 2013–14 A-League
# This is 10 image for 2013–14 A-League
# Images for 2013–14 A-League downloaded successfully.
# Downloading images for subject: Merseybeat
# This is 1 image for Merseybeat
# This is 2 image for Merseybeat
# This is 3 image for Merseybeat
# This is 4 image for Merseybeat
# This is 5 image for Merseybeat
# This is 6 image for Merseybeat
# This is 7 image for Merseybeat
# This is 8 image for Merseybeat
# This is 9 image for Merseybeat
# This is 10 image for Merseybeat
# Images for Merseybeat downloaded successfully.
# Downloading images for subject: George Westinghouse
# This is 1 image for George Westinghouse
# This is 2 image for George Westinghouse
# This is 3 image for George Westinghouse
# This is 4 image for George Westinghouse
# This is 5 image for George Westinghouse
# This is 6 image for George Westinghouse
# This is 7 image for George Westinghouse
# This is 8 image for George Westinghouse
# This is 9 image for George Westinghouse
# This is 10 image for George Westinghouse
# Images for George Westinghouse downloaded successfully.
# Downloading images for subject: Nigella Lawson
# This is 1 image for Nigella Lawson
# This is 2 image for Nigella Lawson
# This is 3 image for Nigella Lawson
# This is 4 image for Nigella Lawson
# This is 5 image for Nigella Lawson
# This is 6 image for Nigella Lawson
# This is 7 image for Nigella Lawson
# This is 8 image for Nigella Lawson
# This is 9 image for Nigella Lawson
# This is 10 image for Nigella Lawson
# Images for Nigella Lawson downloaded successfully.
# Downloading images for subject: Rudolph the Red-Nosed Reindeer
# This is 1 image for Rudolph the Red-Nosed Reindeer
# This is 2 image for Rudolph the Red-Nosed Reindeer
# This is 3 image for Rudolph the Red-Nosed Reindeer
# This is 4 image for Rudolph the Red-Nosed Reindeer
# This is 5 image for Rudolph the Red-Nosed Reindeer
# This is 6 image for Rudolph the Red-Nosed Reindeer
# This is 7 image for Rudolph the Red-Nosed Reindeer
# This is 8 image for Rudolph the Red-Nosed Reindeer
# This is 9 image for Rudolph the Red-Nosed Reindeer
# This is 10 image for Rudolph the Red-Nosed Reindeer
# Images for Rudolph the Red-Nosed Reindeer downloaded successfully.
# Downloading images for subject: Hugh Hefner
# This is 1 image for Hugh Hefner
# This is 2 image for Hugh Hefner
# This is 3 image for Hugh Hefner
# This is 4 image for Hugh Hefner
# This is 5 image for Hugh Hefner
# This is 6 image for Hugh Hefner
# This is 7 image for Hugh Hefner
# This is 8 image for Hugh Hefner
# This is 9 image for Hugh Hefner
# This is 10 image for Hugh Hefner
# Images for Hugh Hefner downloaded successfully.
# Downloading images for subject: Ty Detmer
# This is 1 image for Ty Detmer
# This is 2 image for Ty Detmer
# This is 3 image for Ty Detmer
# This is 4 image for Ty Detmer
# This is 5 image for Ty Detmer
# This is 6 image for Ty Detmer
# This is 7 image for Ty Detmer
# This is 8 image for Ty Detmer
# This is 9 image for Ty Detmer
# This is 10 image for Ty Detmer
# Images for Ty Detmer downloaded successfully.
# Downloading images for subject: Seinäjoki
# This is 1 image for Seinäjoki
# This is 2 image for Seinäjoki
# This is 3 image for Seinäjoki
# This is 4 image for Seinäjoki
# This is 5 image for Seinäjoki
# This is 6 image for Seinäjoki
# This is 7 image for Seinäjoki
# This is 8 image for Seinäjoki
# This is 9 image for Seinäjoki
# This is 10 image for Seinäjoki
# Images for Seinäjoki downloaded successfully.
# Downloading images for subject: Paperback Writer
# This is 1 image for Paperback Writer
# This is 2 image for Paperback Writer
# This is 3 image for Paperback Writer
# This is 4 image for Paperback Writer
# This is 5 image for Paperback Writer
# This is 6 image for Paperback Writer
# This is 7 image for Paperback Writer
# This is 8 image for Paperback Writer
# This is 9 image for Paperback Writer
# This is 10 image for Paperback Writer
# Images for Paperback Writer downloaded successfully.
# Downloading images for subject: TFF Third League
# This is 1 image for TFF Third League
# This is 2 image for TFF Third League
# This is 3 image for TFF Third League
# This is 4 image for TFF Third League
# This is 5 image for TFF Third League
# This is 6 image for TFF Third League
# This is 7 image for TFF Third League
# This is 8 image for TFF Third League
# This is 9 image for TFF Third League
# This is 10 image for TFF Third League
# Images for TFF Third League downloaded successfully.
# Downloading images for subject: Sarah Jessica Parker
# This is 1 image for Sarah Jessica Parker
# This is 2 image for Sarah Jessica Parker
# This is 3 image for Sarah Jessica Parker
# This is 4 image for Sarah Jessica Parker
# This is 5 image for Sarah Jessica Parker
# This is 6 image for Sarah Jessica Parker
# This is 7 image for Sarah Jessica Parker
# This is 8 image for Sarah Jessica Parker
# This is 9 image for Sarah Jessica Parker
# This is 10 image for Sarah Jessica Parker
# Images for Sarah Jessica Parker downloaded successfully.
# Downloading images for subject: Andoni Zubizarreta
# This is 1 image for Andoni Zubizarreta
# This is 2 image for Andoni Zubizarreta
# This is 3 image for Andoni Zubizarreta
# This is 4 image for Andoni Zubizarreta
# This is 5 image for Andoni Zubizarreta
# This is 6 image for Andoni Zubizarreta
# This is 7 image for Andoni Zubizarreta
# This is 8 image for Andoni Zubizarreta
# This is 9 image for Andoni Zubizarreta
# This is 10 image for Andoni Zubizarreta
# Images for Andoni Zubizarreta downloaded successfully.
# Downloading images for subject: James Buchanan Duke
# This is 1 image for James Buchanan Duke
# This is 2 image for James Buchanan Duke
# This is 3 image for James Buchanan Duke
# This is 4 image for James Buchanan Duke
# This is 5 image for James Buchanan Duke
# This is 6 image for James Buchanan Duke
# This is 7 image for James Buchanan Duke
# This is 8 image for James Buchanan Duke
# This is 9 image for James Buchanan Duke
# This is 10 image for James Buchanan Duke
# Images for James Buchanan Duke downloaded successfully.
# Downloading images for subject: Bob Cratchit
# This is 1 image for Bob Cratchit
# This is 2 image for Bob Cratchit
# This is 3 image for Bob Cratchit
# This is 4 image for Bob Cratchit
# This is 5 image for Bob Cratchit
# This is 6 image for Bob Cratchit
# This is 7 image for Bob Cratchit
# This is 8 image for Bob Cratchit
# This is 9 image for Bob Cratchit
# This is 10 image for Bob Cratchit
# Images for Bob Cratchit downloaded successfully.
# Downloading images for subject: Eccellenza
# This is 1 image for Eccellenza
# This is 2 image for Eccellenza
# This is 3 image for Eccellenza
# This is 4 image for Eccellenza
# This is 5 image for Eccellenza
# This is 6 image for Eccellenza
# This is 7 image for Eccellenza
# This is 8 image for Eccellenza
# This is 9 image for Eccellenza
# This is 10 image for Eccellenza
# Images for Eccellenza downloaded successfully.
# Downloading images for subject: The Dharma Bums
# This is 1 image for The Dharma Bums
# This is 2 image for The Dharma Bums
# This is 3 image for The Dharma Bums
# This is 4 image for The Dharma Bums
# This is 5 image for The Dharma Bums
# This is 6 image for The Dharma Bums
# This is 7 image for The Dharma Bums
# This is 8 image for The Dharma Bums
# This is 9 image for The Dharma Bums
# This is 10 image for The Dharma Bums
# Images for The Dharma Bums downloaded successfully.
# Downloading images for subject: Thomas Vanek
# This is 1 image for Thomas Vanek
# This is 2 image for Thomas Vanek
# This is 3 image for Thomas Vanek
# This is 4 image for Thomas Vanek
# This is 5 image for Thomas Vanek
# This is 6 image for Thomas Vanek
# This is 7 image for Thomas Vanek
# This is 8 image for Thomas Vanek
# This is 9 image for Thomas Vanek
# This is 10 image for Thomas Vanek
# Images for Thomas Vanek downloaded successfully.
# Downloading images for subject: Stanford University
# This is 1 image for Stanford University
# This is 2 image for Stanford University
# This is 3 image for Stanford University
# This is 4 image for Stanford University
# This is 5 image for Stanford University
# This is 6 image for Stanford University
# This is 7 image for Stanford University
# This is 8 image for Stanford University
# This is 9 image for Stanford University
# This is 10 image for Stanford University
# Images for Stanford University downloaded successfully.
# Downloading images for subject: Uruguay national football team
# This is 1 image for Uruguay national football team
# This is 2 image for Uruguay national football team
# This is 3 image for Uruguay national football team
# This is 4 image for Uruguay national football team
# This is 5 image for Uruguay national football team
# This is 6 image for Uruguay national football team
# This is 7 image for Uruguay national football team
# This is 8 image for Uruguay national football team
# This is 9 image for Uruguay national football team
# This is 10 image for Uruguay national football team
# Images for Uruguay national football team downloaded successfully.
# Downloading images for subject: Hound Dog Taylor
# This is 1 image for Hound Dog Taylor
# This is 2 image for Hound Dog Taylor
# This is 3 image for Hound Dog Taylor
# This is 4 image for Hound Dog Taylor
# This is 5 image for Hound Dog Taylor
# This is 6 image for Hound Dog Taylor
# This is 7 image for Hound Dog Taylor
# This is 8 image for Hound Dog Taylor
# This is 9 image for Hound Dog Taylor
# This is 10 image for Hound Dog Taylor
# Images for Hound Dog Taylor downloaded successfully.
# Downloading images for subject: Baudouin of Belgium
# This is 1 image for Baudouin of Belgium
# This is 2 image for Baudouin of Belgium
# This is 3 image for Baudouin of Belgium
# This is 4 image for Baudouin of Belgium
# This is 5 image for Baudouin of Belgium
# This is 6 image for Baudouin of Belgium
# This is 7 image for Baudouin of Belgium
# This is 8 image for Baudouin of Belgium
# This is 9 image for Baudouin of Belgium
# This is 10 image for Baudouin of Belgium
# Images for Baudouin of Belgium downloaded successfully.
# Downloading images for subject: Lou Henry Hoover
# This is 1 image for Lou Henry Hoover
# This is 2 image for Lou Henry Hoover
# This is 3 image for Lou Henry Hoover
# This is 4 image for Lou Henry Hoover
# This is 5 image for Lou Henry Hoover
# This is 6 image for Lou Henry Hoover
# This is 7 image for Lou Henry Hoover
# This is 8 image for Lou Henry Hoover
# This is 9 image for Lou Henry Hoover
# This is 10 image for Lou Henry Hoover
# Images for Lou Henry Hoover downloaded successfully.
# Downloading images for subject: WWE Superstars
# This is 1 image for WWE Superstars
# This is 2 image for WWE Superstars
# This is 3 image for WWE Superstars
# This is 4 image for WWE Superstars
# This is 5 image for WWE Superstars
# This is 6 image for WWE Superstars
# This is 7 image for WWE Superstars
# This is 8 image for WWE Superstars
# This is 9 image for WWE Superstars
# This is 10 image for WWE Superstars
# Images for WWE Superstars downloaded successfully.
# Downloading images for subject: Raytheon
# This is 1 image for Raytheon
# This is 2 image for Raytheon
# This is 3 image for Raytheon
# This is 4 image for Raytheon
# This is 5 image for Raytheon
# This is 6 image for Raytheon
# This is 7 image for Raytheon
# This is 8 image for Raytheon
# This is 9 image for Raytheon
# This is 10 image for Raytheon
# Images for Raytheon downloaded successfully.
# Downloading images for subject: Club Atlético Lanús
# This is 1 image for Club Atlético Lanús
# This is 2 image for Club Atlético Lanús
# This is 3 image for Club Atlético Lanús
# This is 4 image for Club Atlético Lanús
# This is 5 image for Club Atlético Lanús
# This is 6 image for Club Atlético Lanús
# This is 7 image for Club Atlético Lanús
# This is 8 image for Club Atlético Lanús
# This is 9 image for Club Atlético Lanús
# This is 10 image for Club Atlético Lanús
# Images for Club Atlético Lanús downloaded successfully.
# Downloading images for subject: Charlie Brown
# This is 1 image for Charlie Brown
# This is 2 image for Charlie Brown
# This is 3 image for Charlie Brown
# This is 4 image for Charlie Brown
# This is 5 image for Charlie Brown
# This is 6 image for Charlie Brown
# This is 7 image for Charlie Brown
# This is 8 image for Charlie Brown
# This is 9 image for Charlie Brown
# This is 10 image for Charlie Brown
# Images for Charlie Brown downloaded successfully.
# Downloading images for subject: S.S.C. Napoli
# This is 1 image for S.S.C. Napoli
# This is 2 image for S.S.C. Napoli
# This is 3 image for S.S.C. Napoli
# This is 4 image for S.S.C. Napoli
# This is 5 image for S.S.C. Napoli
# This is 6 image for S.S.C. Napoli
# This is 7 image for S.S.C. Napoli
# This is 8 image for S.S.C. Napoli
# This is 9 image for S.S.C. Napoli
# This is 10 image for S.S.C. Napoli
# Images for S.S.C. Napoli downloaded successfully.
# Downloading images for subject: Muhammad Ali
# This is 1 image for Muhammad Ali
# This is 2 image for Muhammad Ali
# This is 3 image for Muhammad Ali
# This is 4 image for Muhammad Ali
# This is 5 image for Muhammad Ali
# This is 6 image for Muhammad Ali
# This is 7 image for Muhammad Ali
# This is 8 image for Muhammad Ali
# This is 9 image for Muhammad Ali
# This is 10 image for Muhammad Ali
# Images for Muhammad Ali downloaded successfully.
# Downloading images for subject: 1984
# This is 1 image for 1984
# This is 2 image for 1984
# This is 3 image for 1984
# This is 4 image for 1984
# This is 5 image for 1984
# This is 6 image for 1984
# This is 7 image for 1984
# This is 8 image for 1984
# This is 9 image for 1984
# This is 10 image for 1984
# Images for 1984 downloaded successfully.
# Downloading images for subject: Carnatic music
# This is 1 image for Carnatic music
# This is 2 image for Carnatic music
# This is 3 image for Carnatic music
# This is 4 image for Carnatic music
# This is 5 image for Carnatic music
# This is 6 image for Carnatic music
# This is 7 image for Carnatic music
# This is 8 image for Carnatic music
# This is 9 image for Carnatic music
# This is 10 image for Carnatic music
# Images for Carnatic music downloaded successfully.
# Downloading images for subject: Das Kapital
# This is 1 image for Das Kapital
# This is 2 image for Das Kapital
# This is 3 image for Das Kapital
# This is 4 image for Das Kapital
# This is 5 image for Das Kapital
# This is 6 image for Das Kapital
# This is 7 image for Das Kapital
# This is 8 image for Das Kapital
# This is 9 image for Das Kapital
# This is 10 image for Das Kapital
# Images for Das Kapital downloaded successfully.
# Downloading images for subject: Jean-Luc Dehaene
# This is 1 image for Jean-Luc Dehaene
# This is 2 image for Jean-Luc Dehaene
# This is 3 image for Jean-Luc Dehaene
# This is 4 image for Jean-Luc Dehaene
# This is 5 image for Jean-Luc Dehaene
# This is 6 image for Jean-Luc Dehaene
# This is 7 image for Jean-Luc Dehaene
# This is 8 image for Jean-Luc Dehaene
# This is 9 image for Jean-Luc Dehaene
# This is 10 image for Jean-Luc Dehaene
# Images for Jean-Luc Dehaene downloaded successfully.
# Downloading images for subject: Luc Longley
# This is 1 image for Luc Longley
# This is 2 image for Luc Longley
# This is 3 image for Luc Longley
# This is 4 image for Luc Longley
# This is 5 image for Luc Longley
# This is 6 image for Luc Longley
# This is 7 image for Luc Longley
# This is 8 image for Luc Longley
# This is 9 image for Luc Longley
# This is 10 image for Luc Longley
# Images for Luc Longley downloaded successfully.
# Downloading images for subject: Simon Cameron
# This is 1 image for Simon Cameron
# This is 2 image for Simon Cameron
# This is 3 image for Simon Cameron
# This is 4 image for Simon Cameron
# This is 5 image for Simon Cameron
# This is 6 image for Simon Cameron
# This is 7 image for Simon Cameron
# This is 8 image for Simon Cameron
# This is 9 image for Simon Cameron
# This is 10 image for Simon Cameron
# Images for Simon Cameron downloaded successfully.
# Downloading images for subject: 1994–95 Coppa Italia
# This is 1 image for 1994–95 Coppa Italia
# This is 2 image for 1994–95 Coppa Italia
# This is 3 image for 1994–95 Coppa Italia
# This is 4 image for 1994–95 Coppa Italia
# This is 5 image for 1994–95 Coppa Italia
# This is 6 image for 1994–95 Coppa Italia
# This is 7 image for 1994–95 Coppa Italia
# This is 8 image for 1994–95 Coppa Italia
# This is 9 image for 1994–95 Coppa Italia
# This is 10 image for 1994–95 Coppa Italia
# Images for 1994–95 Coppa Italia downloaded successfully.
# Downloading images for subject: Lakshmi Mittal
# This is 1 image for Lakshmi Mittal
# This is 2 image for Lakshmi Mittal
# This is 3 image for Lakshmi Mittal
# This is 4 image for Lakshmi Mittal
# This is 5 image for Lakshmi Mittal
# This is 6 image for Lakshmi Mittal
# This is 7 image for Lakshmi Mittal
# This is 8 image for Lakshmi Mittal
# This is 9 image for Lakshmi Mittal
# This is 10 image for Lakshmi Mittal
# Images for Lakshmi Mittal downloaded successfully.
# Downloading images for subject: AS Cherbourg Football
# This is 1 image for AS Cherbourg Football
# This is 2 image for AS Cherbourg Football
# This is 3 image for AS Cherbourg Football
# This is 4 image for AS Cherbourg Football
# This is 5 image for AS Cherbourg Football
# This is 6 image for AS Cherbourg Football
# This is 7 image for AS Cherbourg Football
# This is 8 image for AS Cherbourg Football
# This is 9 image for AS Cherbourg Football
# This is 10 image for AS Cherbourg Football
# Images for AS Cherbourg Football downloaded successfully.
# Downloading images for subject: The Gambler
# This is 1 image for The Gambler
# This is 2 image for The Gambler
# This is 3 image for The Gambler
# This is 4 image for The Gambler
# This is 5 image for The Gambler
# This is 6 image for The Gambler
# This is 7 image for The Gambler
# This is 8 image for The Gambler
# This is 9 image for The Gambler
# This is 10 image for The Gambler
# Images for The Gambler downloaded successfully.
# Downloading images for subject: 2014-15 Premier League
# This is 1 image for 2014-15 Premier League
# This is 2 image for 2014-15 Premier League
# This is 3 image for 2014-15 Premier League
# This is 4 image for 2014-15 Premier League
# This is 5 image for 2014-15 Premier League
# This is 6 image for 2014-15 Premier League
# This is 7 image for 2014-15 Premier League
# This is 8 image for 2014-15 Premier League
# This is 9 image for 2014-15 Premier League
# This is 10 image for 2014-15 Premier League
# Images for 2014-15 Premier League downloaded successfully.
# Downloading images for subject: Nic Pizzolatto
# This is 1 image for Nic Pizzolatto
# This is 2 image for Nic Pizzolatto
# This is 3 image for Nic Pizzolatto
# This is 4 image for Nic Pizzolatto
# This is 5 image for Nic Pizzolatto
# This is 6 image for Nic Pizzolatto
# This is 7 image for Nic Pizzolatto
# This is 8 image for Nic Pizzolatto
# This is 9 image for Nic Pizzolatto
# This is 10 image for Nic Pizzolatto
# Images for Nic Pizzolatto downloaded successfully.
# Downloading images for subject: Thornton Wilder
# This is 1 image for Thornton Wilder
# This is 2 image for Thornton Wilder
# This is 3 image for Thornton Wilder
# This is 4 image for Thornton Wilder
# This is 5 image for Thornton Wilder
# This is 6 image for Thornton Wilder
# This is 7 image for Thornton Wilder
# This is 8 image for Thornton Wilder
# This is 9 image for Thornton Wilder
# This is 10 image for Thornton Wilder
# Images for Thornton Wilder downloaded successfully.
# Downloading images for subject: Hank Azaria
# This is 1 image for Hank Azaria
# This is 2 image for Hank Azaria
# This is 3 image for Hank Azaria
# This is 4 image for Hank Azaria
# This is 5 image for Hank Azaria
# This is 6 image for Hank Azaria
# This is 7 image for Hank Azaria
# This is 8 image for Hank Azaria
# This is 9 image for Hank Azaria
# This is 10 image for Hank Azaria
# Images for Hank Azaria downloaded successfully.
# Downloading images for subject: Star Wars
# This is 1 image for Star Wars
# This is 2 image for Star Wars
# This is 3 image for Star Wars
# This is 4 image for Star Wars
# This is 5 image for Star Wars
# This is 6 image for Star Wars
# This is 7 image for Star Wars
# This is 8 image for Star Wars
# This is 9 image for Star Wars
# This is 10 image for Star Wars
# Images for Star Wars downloaded successfully.
# Downloading images for subject: Xcode
# This is 1 image for Xcode
# This is 2 image for Xcode
# This is 3 image for Xcode
# This is 4 image for Xcode
# This is 5 image for Xcode
# This is 6 image for Xcode
# This is 7 image for Xcode
# This is 8 image for Xcode
# This is 9 image for Xcode
# This is 10 image for Xcode
# Images for Xcode downloaded successfully.
# Downloading images for subject: Marcelo Rebelo de Sousa
# This is 1 image for Marcelo Rebelo de Sousa
# This is 2 image for Marcelo Rebelo de Sousa
# This is 3 image for Marcelo Rebelo de Sousa
# This is 4 image for Marcelo Rebelo de Sousa
# This is 5 image for Marcelo Rebelo de Sousa
# This is 6 image for Marcelo Rebelo de Sousa
# This is 7 image for Marcelo Rebelo de Sousa
# This is 8 image for Marcelo Rebelo de Sousa
# This is 9 image for Marcelo Rebelo de Sousa
# This is 10 image for Marcelo Rebelo de Sousa
# Images for Marcelo Rebelo de Sousa downloaded successfully.
# Downloading images for subject: Leo XIII
# This is 1 image for Leo XIII
# This is 2 image for Leo XIII
# This is 3 image for Leo XIII
# This is 4 image for Leo XIII
# This is 5 image for Leo XIII
# This is 6 image for Leo XIII
# This is 7 image for Leo XIII
# This is 8 image for Leo XIII
# This is 9 image for Leo XIII
# This is 10 image for Leo XIII
# Images for Leo XIII downloaded successfully.
# Downloading images for subject: University of Michigan
# This is 1 image for University of Michigan
# This is 2 image for University of Michigan
# This is 3 image for University of Michigan
# This is 4 image for University of Michigan
# This is 5 image for University of Michigan
# This is 6 image for University of Michigan
# This is 7 image for University of Michigan
# This is 8 image for University of Michigan
# This is 9 image for University of Michigan
# This is 10 image for University of Michigan
# Images for University of Michigan downloaded successfully.
# Downloading images for subject: David Hirst
# This is 1 image for David Hirst
# This is 2 image for David Hirst
# This is 3 image for David Hirst
# This is 4 image for David Hirst
# This is 5 image for David Hirst
# This is 6 image for David Hirst
# This is 7 image for David Hirst
# This is 8 image for David Hirst
# This is 9 image for David Hirst
# This is 10 image for David Hirst
# Images for David Hirst downloaded successfully.
# Downloading images for subject: Azerbaijan Cup
# This is 1 image for Azerbaijan Cup
# This is 2 image for Azerbaijan Cup
# This is 3 image for Azerbaijan Cup
# This is 4 image for Azerbaijan Cup
# This is 5 image for Azerbaijan Cup
# This is 6 image for Azerbaijan Cup
# This is 7 image for Azerbaijan Cup
# This is 8 image for Azerbaijan Cup
# This is 9 image for Azerbaijan Cup
# This is 10 image for Azerbaijan Cup
# Images for Azerbaijan Cup downloaded successfully.
# Downloading images for subject: Safari
# This is 1 image for Safari
# This is 2 image for Safari
# This is 3 image for Safari
# This is 4 image for Safari
# This is 5 image for Safari
# This is 6 image for Safari
# This is 7 image for Safari
# This is 8 image for Safari
# This is 9 image for Safari
# This is 10 image for Safari
# Images for Safari downloaded successfully.
# Downloading images for subject: The New York Times
# This is 1 image for The New York Times
# This is 2 image for The New York Times
# This is 3 image for The New York Times
# This is 4 image for The New York Times
# This is 5 image for The New York Times
# This is 6 image for The New York Times
# This is 7 image for The New York Times
# This is 8 image for The New York Times
# This is 9 image for The New York Times
# This is 10 image for The New York Times
# Images for The New York Times downloaded successfully.
# Downloading images for subject: Robert Parish
# This is 1 image for Robert Parish
# This is 2 image for Robert Parish
# This is 3 image for Robert Parish
# This is 4 image for Robert Parish
# This is 5 image for Robert Parish
# This is 6 image for Robert Parish
# This is 7 image for Robert Parish
# This is 8 image for Robert Parish
# This is 9 image for Robert Parish
# This is 10 image for Robert Parish
# Images for Robert Parish downloaded successfully.
# Downloading images for subject: Eric Davis
# This is 1 image for Eric Davis
# This is 2 image for Eric Davis
# This is 3 image for Eric Davis
# This is 4 image for Eric Davis
# This is 5 image for Eric Davis
# This is 6 image for Eric Davis
# This is 7 image for Eric Davis
# This is 8 image for Eric Davis
# This is 9 image for Eric Davis
# This is 10 image for Eric Davis
# Images for Eric Davis downloaded successfully.
# Downloading images for subject: Kenley Jansen
# This is 1 image for Kenley Jansen
# This is 2 image for Kenley Jansen
# This is 3 image for Kenley Jansen
# This is 4 image for Kenley Jansen
# This is 5 image for Kenley Jansen
# This is 6 image for Kenley Jansen
# This is 7 image for Kenley Jansen
# This is 8 image for Kenley Jansen
# This is 9 image for Kenley Jansen
# This is 10 image for Kenley Jansen
# Images for Kenley Jansen downloaded successfully.
# Downloading images for subject: Thiago Silva
# This is 1 image for Thiago Silva
# This is 2 image for Thiago Silva
# This is 3 image for Thiago Silva
# This is 4 image for Thiago Silva
# This is 5 image for Thiago Silva
# This is 6 image for Thiago Silva
# This is 7 image for Thiago Silva
# This is 8 image for Thiago Silva
# This is 9 image for Thiago Silva
# This is 10 image for Thiago Silva
# Images for Thiago Silva downloaded successfully.
# Downloading images for subject: Love Me Do
# This is 1 image for Love Me Do
# This is 2 image for Love Me Do
# This is 3 image for Love Me Do
# This is 4 image for Love Me Do
# This is 5 image for Love Me Do
# This is 6 image for Love Me Do
# This is 7 image for Love Me Do
# This is 8 image for Love Me Do
# This is 9 image for Love Me Do
# This is 10 image for Love Me Do
# Images for Love Me Do downloaded successfully.
# Downloading images for subject: Dave Filoni
# This is 1 image for Dave Filoni
# This is 2 image for Dave Filoni
# This is 3 image for Dave Filoni
# This is 4 image for Dave Filoni
# This is 5 image for Dave Filoni
# This is 6 image for Dave Filoni
# This is 7 image for Dave Filoni
# This is 8 image for Dave Filoni
# This is 9 image for Dave Filoni
# This is 10 image for Dave Filoni
# Images for Dave Filoni downloaded successfully.
# Downloading images for subject: Twin Peaks
# This is 1 image for Twin Peaks
# This is 2 image for Twin Peaks
# This is 3 image for Twin Peaks
# This is 4 image for Twin Peaks
# This is 5 image for Twin Peaks
# This is 6 image for Twin Peaks
# This is 7 image for Twin Peaks
# This is 8 image for Twin Peaks
# This is 9 image for Twin Peaks
# This is 10 image for Twin Peaks
# Images for Twin Peaks downloaded successfully.
# Downloading images for subject: Blake Shelton
# This is 1 image for Blake Shelton
# This is 2 image for Blake Shelton
# This is 3 image for Blake Shelton
# This is 4 image for Blake Shelton
# This is 5 image for Blake Shelton
# This is 6 image for Blake Shelton
# This is 7 image for Blake Shelton
# This is 8 image for Blake Shelton
# This is 9 image for Blake Shelton
# This is 10 image for Blake Shelton
# Images for Blake Shelton downloaded successfully.
# Downloading images for subject: Jaguar XJS
# This is 1 image for Jaguar XJS
# This is 2 image for Jaguar XJS
# This is 3 image for Jaguar XJS
# This is 4 image for Jaguar XJS
# This is 5 image for Jaguar XJS
# This is 6 image for Jaguar XJS
# This is 7 image for Jaguar XJS
# This is 8 image for Jaguar XJS
# This is 9 image for Jaguar XJS
# This is 10 image for Jaguar XJS
# Images for Jaguar XJS downloaded successfully.
# Downloading images for subject: Joseph Story
# This is 1 image for Joseph Story
# This is 2 image for Joseph Story
# This is 3 image for Joseph Story
# This is 4 image for Joseph Story
# This is 5 image for Joseph Story
# This is 6 image for Joseph Story
# This is 7 image for Joseph Story
# This is 8 image for Joseph Story
# This is 9 image for Joseph Story
# This is 10 image for Joseph Story
# Images for Joseph Story downloaded successfully.
# Downloading images for subject: Pinocchio
# This is 1 image for Pinocchio
# This is 2 image for Pinocchio
# This is 3 image for Pinocchio
# This is 4 image for Pinocchio
# This is 5 image for Pinocchio
# This is 6 image for Pinocchio
# This is 7 image for Pinocchio
# This is 8 image for Pinocchio
# This is 9 image for Pinocchio
# This is 10 image for Pinocchio
# Images for Pinocchio downloaded successfully.
# Downloading images for subject: Niccolò Machiavelli
# This is 1 image for Niccolò Machiavelli
# This is 2 image for Niccolò Machiavelli
# This is 3 image for Niccolò Machiavelli
# This is 4 image for Niccolò Machiavelli
# This is 5 image for Niccolò Machiavelli
# This is 6 image for Niccolò Machiavelli
# This is 7 image for Niccolò Machiavelli
# This is 8 image for Niccolò Machiavelli
# This is 9 image for Niccolò Machiavelli
# This is 10 image for Niccolò Machiavelli
# Images for Niccolò Machiavelli downloaded successfully.
# Downloading images for subject: Wellington Phoenix FC
# This is 1 image for Wellington Phoenix FC
# This is 2 image for Wellington Phoenix FC
# This is 3 image for Wellington Phoenix FC
# This is 4 image for Wellington Phoenix FC
# This is 5 image for Wellington Phoenix FC
# This is 6 image for Wellington Phoenix FC
# This is 7 image for Wellington Phoenix FC
# This is 8 image for Wellington Phoenix FC
# This is 9 image for Wellington Phoenix FC
# This is 10 image for Wellington Phoenix FC
# Images for Wellington Phoenix FC downloaded successfully.
# Downloading images for subject: Gulliver's Travels
# This is 1 image for Gulliver's Travels
# This is 2 image for Gulliver's Travels
# This is 3 image for Gulliver's Travels
# This is 4 image for Gulliver's Travels
# This is 5 image for Gulliver's Travels
# This is 6 image for Gulliver's Travels
# This is 7 image for Gulliver's Travels
# This is 8 image for Gulliver's Travels
# This is 9 image for Gulliver's Travels
# This is 10 image for Gulliver's Travels
# Images for Gulliver's Travels downloaded successfully.
# Downloading images for subject: 24
# This is 1 image for 24
# This is 2 image for 24
# This is 3 image for 24
# This is 4 image for 24
# This is 5 image for 24
# This is 6 image for 24
# This is 7 image for 24
# This is 8 image for 24
# This is 9 image for 24
# This is 10 image for 24
# Images for 24 downloaded successfully.
# Downloading images for subject: Seattle Sounders FC U-23
# This is 1 image for Seattle Sounders FC U-23
# This is 2 image for Seattle Sounders FC U-23
# This is 3 image for Seattle Sounders FC U-23
# This is 4 image for Seattle Sounders FC U-23
# This is 5 image for Seattle Sounders FC U-23
# This is 6 image for Seattle Sounders FC U-23
# This is 7 image for Seattle Sounders FC U-23
# This is 8 image for Seattle Sounders FC U-23
# This is 9 image for Seattle Sounders FC U-23
# This is 10 image for Seattle Sounders FC U-23
# Images for Seattle Sounders FC U-23 downloaded successfully.
# Downloading images for subject: Horace
# This is 1 image for Horace
# This is 2 image for Horace
# This is 3 image for Horace
# This is 4 image for Horace
# This is 5 image for Horace
# This is 6 image for Horace
# This is 7 image for Horace
# This is 8 image for Horace
# This is 9 image for Horace
# This is 10 image for Horace
# Images for Horace downloaded successfully.
# Downloading images for subject: Fujieda MYFC
# This is 1 image for Fujieda MYFC
# This is 2 image for Fujieda MYFC
# This is 3 image for Fujieda MYFC
# This is 4 image for Fujieda MYFC
# This is 5 image for Fujieda MYFC
# This is 6 image for Fujieda MYFC
# This is 7 image for Fujieda MYFC
# This is 8 image for Fujieda MYFC
# This is 9 image for Fujieda MYFC
# This is 10 image for Fujieda MYFC
# Images for Fujieda MYFC downloaded successfully.
# Downloading images for subject: Being and Time
# This is 1 image for Being and Time
# This is 2 image for Being and Time
# This is 3 image for Being and Time
# This is 4 image for Being and Time
# This is 5 image for Being and Time
# This is 6 image for Being and Time
# This is 7 image for Being and Time
# This is 8 image for Being and Time
# This is 9 image for Being and Time
# This is 10 image for Being and Time
# Images for Being and Time downloaded successfully.
# All images downloaded successfully.

# %%
# date：2020.5.25
# author:pmy
# aim:爬取google图片
#问题在于，不能保证所爬为所见

from selenium import webdriver
import time
import os
import requests

# 修改keyword便可以修改搜索关键词 建议也修改存储目录
keyword = 'cat'
url = 'https://www.google.com.hk/search?q=' + keyword + '&source=lnms&tbm=isch'


class Crawler_google_images:
    # 初始化
    def __init__(self):
        self.url = url

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        browser = webdriver.Chrome(options=chrome_options)
        # 访问url
        browser.get(self.url)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        return browser

    # 下载图片
    def download_images(self, browser, num=5):
        #存储路径
        picpath = './cat'
        # 路径不存在时创建一个
        if not os.path.exists(picpath): os.makedirs(picpath)

        count = 0  # 图片序号
        pos = 0
        # print(num)

        while (True):
            try:
                # 向下滑动
                js = 'var q=document.documentElement.scrollTop=' + str(pos)
                pos += 500
                browser.execute_script(js)
                time.sleep(1)
                # 找到图片
                # html = browser.page_source#也可以抓取当前页面的html文本，然后用beautifulsoup来抓取
                # 直接通过tag_name来抓取是最简单的，比较方便
                img_elements = browser.find_elements_by_xpath('//a[@class="wXeWr islib nfEiy mM5pbd"]')
                try:
                    for img_element in img_elements:
                        #点开大图页面
                        img_element.click()
                        time.sleep(0.5)
                        try:
                            # 这里balabala里面有好几个，所以要过滤一下
                            # 取名好烦哦···
                            balabalas = browser.find_elements_by_xpath('//img[@class="n3VNCb"]')

                            if (balabalas):
                                for balabala in balabalas:
                                    src = balabala.get_attribute('src')
                                    #过滤掉缩略图和无关干扰信息
                                    if src.startswith('http') and not src.startswith(
                                            'https://encrypted-tbn0.gstatic.com'):
                                        print('Found' + str(count) + 'st image url')
                                        # img_url_dic.append(src)
                                        self.save_img(count, src, picpath)
                                        count += 1
                                        #爬取到指定数量图片后退出
                                        if (count >= num):
                                            return "stop"
                        except:
                            print('获取图片失败')

                    #回退
                    browser.back()
                    time.sleep(0.3)
                except:
                    print('获取页面失败')
            except:
                print("划不动了")

    def save_img(self, count, img_src, picpath):
        filename = picpath + '/' + str(count) + '.jpg'
        r = requests.get(img_src)
        with open(filename, 'wb') as f:
            f.write(r.content)
        f.close()

    def run(self):
        self.__init__()
        browser = self.init_browser()
        self.download_images(browser, 100)  # 可以修改爬取的图片数
        browser.close()
        print("############爬取完成")


if __name__ == '__main__':
    craw = Crawler_google_images()
    craw.run()
