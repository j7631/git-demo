# %%
# date: 2020.5.25
# author: pmy
# aim: 爬取Google图片

from selenium import webdriver
import time
import os
import requests
from selenium.webdriver.common.by import By
import pandas as pd



class Crawler_google_images:
    # 初始化
    def __init__(self, index , keyword):
        self.keyword = keyword
        self.url = 'https://www.google.com.hk/search?q=' + keyword + '&tbm=isch'
        self.index = index

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        chrome_options.add_argument("--headless")  # 无头模式
        chrome_options.add_argument("--disable-gpu")
        chrome_options.add_argument("--window-size=1920x1080")
        browser = webdriver.Chrome(options=chrome_options)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        # 访问url
        browser.get(self.url)
        return browser

    # 下载图片
    def download_images(self, browser, num_images=5):
        picpath = f'./images/{str(self.index) + "_" + self.keyword.replace(" ", "_")}'
        # 路径不存在时创建一个
        if not os.path.exists(picpath):
            os.makedirs(picpath)
        # 记录下载过的图片地址，避免重复下载
        img_url_dic = []

        count = 0  # 图片序号
        pos = 0

        while count < num_images:
            pos += 500
            # 向下滑动
            js = 'var q=document.documentElement.scrollTop=' + str(pos)
            browser.execute_script(js)
            time.sleep(1)
            # 找到图片
            img_elements = browser.find_elements(By.TAG_NAME, 'img')
            # 遍历抓到的webElement
            for img_element in img_elements:
                if count >= num_images:
                    break
                img_url = img_element.get_attribute('src')
                # 前几个图片的url太长，不是图片的url，先过滤掉，爬后面的
                if isinstance(img_url, str):
                    if len(img_url) <= 200:
                        # 将干扰的google图标筛去
                        if 'images' in img_url:
                            # 判断是否已经爬过，因为每次爬取当前窗口，或许会重复
                            if img_url not in img_url_dic:
                                try:
                                    img_url_dic.append(img_url)
                                    # 下载并保存图片到当前目录下
                                    filename = f"./images/{str(self.index) + '_' + self.keyword.replace(' ', '_')}/" + str(count) + ".jpg"
                                    r = requests.get(img_url, timeout=10)
                                    with open(filename, 'wb') as f:
                                        f.write(r.content)
                                    count += 1
                                    print(f'This is {count} image for {self.keyword}')
                                    # 防止反爬机制
                                    time.sleep(0.2)
                                except Exception as e:
                                    print(f'Failed to download image {img_url}: {e}')

    def run(self, num_images=5):
        browser = self.init_browser()
        self.download_images(browser, num_images)
        browser.close()
        print(f"Images for {self.keyword} downloaded successfully.")

if __name__ == '__main__':
    num_images_to_download = 5  # 每个主题要下载的图片数量
    # 从CSV文件中读取数据
    csv_file_path = '/Users/bytedance/Desktop/Project/consistency/data/CF-triples_labeled.csv'
    df = pd.read_csv(csv_file_path)
    start_index = 500
    end_index = 1000
    # 取前1000个subject
    subjects = df['subject'].unique()[start_index:end_index]

    index = start_index
    for subject in subjects:
        print(f"Downloading images for subject: {subject}")
        crawler = Crawler_google_images(index = index, keyword=subject)
        crawler.run(num_images=num_images_to_download)
        index += 1
    print("All images downloaded successfully.")
# Out:
# Downloading images for subject: The Guild
# This is 1 image for The Guild
# This is 2 image for The Guild
# This is 3 image for The Guild
# This is 4 image for The Guild
# This is 5 image for The Guild
# Images for The Guild downloaded successfully.
# Downloading images for subject: University of Ghana
# This is 1 image for University of Ghana
# This is 2 image for University of Ghana
# This is 3 image for University of Ghana
# This is 4 image for University of Ghana
# This is 5 image for University of Ghana
# Images for University of Ghana downloaded successfully.
# Downloading images for subject: Steve Mandanda
# This is 1 image for Steve Mandanda
# This is 2 image for Steve Mandanda
# This is 3 image for Steve Mandanda
# This is 4 image for Steve Mandanda
# This is 5 image for Steve Mandanda
# Images for Steve Mandanda downloaded successfully.
# Downloading images for subject: Jack Aubrey
# This is 1 image for Jack Aubrey
# This is 2 image for Jack Aubrey
# This is 3 image for Jack Aubrey
# This is 4 image for Jack Aubrey
# This is 5 image for Jack Aubrey
# Images for Jack Aubrey downloaded successfully.
# Downloading images for subject: Luís de Camões
# This is 1 image for Luís de Camões
# This is 2 image for Luís de Camões
# This is 3 image for Luís de Camões
# This is 4 image for Luís de Camões
# This is 5 image for Luís de Camões
# Images for Luís de Camões downloaded successfully.
# Downloading images for subject: Oscar Wilde
# This is 1 image for Oscar Wilde
# This is 2 image for Oscar Wilde
# This is 3 image for Oscar Wilde
# This is 4 image for Oscar Wilde
# This is 5 image for Oscar Wilde
# Images for Oscar Wilde downloaded successfully.
# Downloading images for subject: Apple Pay
# This is 1 image for Apple Pay
# This is 2 image for Apple Pay
# This is 3 image for Apple Pay
# This is 4 image for Apple Pay
# This is 5 image for Apple Pay
# Images for Apple Pay downloaded successfully.
# Downloading images for subject: 2014 World Judo Championships
# This is 1 image for 2014 World Judo Championships
# This is 2 image for 2014 World Judo Championships
# This is 3 image for 2014 World Judo Championships
# This is 4 image for 2014 World Judo Championships
# This is 5 image for 2014 World Judo Championships
# Images for 2014 World Judo Championships downloaded successfully.
# Downloading images for subject: Arvind Kejriwal
# This is 1 image for Arvind Kejriwal
# This is 2 image for Arvind Kejriwal
# This is 3 image for Arvind Kejriwal
# This is 4 image for Arvind Kejriwal
# This is 5 image for Arvind Kejriwal
# Images for Arvind Kejriwal downloaded successfully.
# Downloading images for subject: Tom Cruise
# This is 1 image for Tom Cruise
# This is 2 image for Tom Cruise
# This is 3 image for Tom Cruise
# This is 4 image for Tom Cruise
# This is 5 image for Tom Cruise
# Images for Tom Cruise downloaded successfully.
# Downloading images for subject: Jim Hawkins
# This is 1 image for Jim Hawkins
# This is 2 image for Jim Hawkins
# This is 3 image for Jim Hawkins
# This is 4 image for Jim Hawkins
# This is 5 image for Jim Hawkins
# Images for Jim Hawkins downloaded successfully.
# Downloading images for subject: Club Atlético Douglas Haig
# This is 1 image for Club Atlético Douglas Haig
# This is 2 image for Club Atlético Douglas Haig
# This is 3 image for Club Atlético Douglas Haig
# This is 4 image for Club Atlético Douglas Haig
# This is 5 image for Club Atlético Douglas Haig
# Images for Club Atlético Douglas Haig downloaded successfully.
# Downloading images for subject: Ovid
# This is 1 image for Ovid
# This is 2 image for Ovid
# This is 3 image for Ovid
# This is 4 image for Ovid
# This is 5 image for Ovid
# Images for Ovid downloaded successfully.
# Downloading images for subject: Kim Kardashian
# This is 1 image for Kim Kardashian
# This is 2 image for Kim Kardashian
# This is 3 image for Kim Kardashian
# This is 4 image for Kim Kardashian
# This is 5 image for Kim Kardashian
# Images for Kim Kardashian downloaded successfully.
# Downloading images for subject: Roald Dahl
# This is 1 image for Roald Dahl
# This is 2 image for Roald Dahl
# This is 3 image for Roald Dahl
# This is 4 image for Roald Dahl
# This is 5 image for Roald Dahl
# Images for Roald Dahl downloaded successfully.
# Downloading images for subject: Steve Ballmer
# This is 1 image for Steve Ballmer
# This is 2 image for Steve Ballmer
# This is 3 image for Steve Ballmer
# This is 4 image for Steve Ballmer
# This is 5 image for Steve Ballmer
# Images for Steve Ballmer downloaded successfully.
# Downloading images for subject: José Mourinho
# This is 1 image for José Mourinho
# This is 2 image for José Mourinho
# This is 3 image for José Mourinho
# This is 4 image for José Mourinho
# This is 5 image for José Mourinho
# Images for José Mourinho downloaded successfully.
# Downloading images for subject: Matt Smith
# This is 1 image for Matt Smith
# This is 2 image for Matt Smith
# This is 3 image for Matt Smith
# This is 4 image for Matt Smith
# This is 5 image for Matt Smith
# Images for Matt Smith downloaded successfully.
# Downloading images for subject: Australia
# This is 1 image for Australia
# This is 2 image for Australia
# This is 3 image for Australia
# This is 4 image for Australia
# This is 5 image for Australia
# Images for Australia downloaded successfully.
# Downloading images for subject: Hanoch Levin
# This is 1 image for Hanoch Levin
# This is 2 image for Hanoch Levin
# This is 3 image for Hanoch Levin
# This is 4 image for Hanoch Levin
# This is 5 image for Hanoch Levin
# Images for Hanoch Levin downloaded successfully.
# Downloading images for subject: Chanakya
# This is 1 image for Chanakya
# This is 2 image for Chanakya
# This is 3 image for Chanakya
# This is 4 image for Chanakya
# This is 5 image for Chanakya
# Images for Chanakya downloaded successfully.
# Downloading images for subject: United Kingdom
# This is 1 image for United Kingdom
# This is 2 image for United Kingdom
# This is 3 image for United Kingdom
# This is 4 image for United Kingdom
# This is 5 image for United Kingdom
# Images for United Kingdom downloaded successfully.
# Downloading images for subject: Loyola Ramblers Men's Basketball
# This is 1 image for Loyola Ramblers Men's Basketball
# This is 2 image for Loyola Ramblers Men's Basketball
# This is 3 image for Loyola Ramblers Men's Basketball
# This is 4 image for Loyola Ramblers Men's Basketball
# This is 5 image for Loyola Ramblers Men's Basketball
# Images for Loyola Ramblers Men's Basketball downloaded successfully.
# Downloading images for subject: Chennai
# This is 1 image for Chennai
# This is 2 image for Chennai
# This is 3 image for Chennai
# This is 4 image for Chennai
# This is 5 image for Chennai
# Images for Chennai downloaded successfully.
# Downloading images for subject: Executive Order 6102
# This is 1 image for Executive Order 6102
# This is 2 image for Executive Order 6102
# This is 3 image for Executive Order 6102
# This is 4 image for Executive Order 6102
# This is 5 image for Executive Order 6102
# Images for Executive Order 6102 downloaded successfully.
# Downloading images for subject: Damian Lillard
# This is 1 image for Damian Lillard
# This is 2 image for Damian Lillard
# This is 3 image for Damian Lillard
# This is 4 image for Damian Lillard
# This is 5 image for Damian Lillard
# Images for Damian Lillard downloaded successfully.
# Downloading images for subject: The Witcher
# This is 1 image for The Witcher
# This is 2 image for The Witcher
# This is 3 image for The Witcher
# This is 4 image for The Witcher
# This is 5 image for The Witcher
# Images for The Witcher downloaded successfully.
# Downloading images for subject: Robert Peel
# This is 1 image for Robert Peel
# This is 2 image for Robert Peel
# This is 3 image for Robert Peel
# This is 4 image for Robert Peel
# This is 5 image for Robert Peel
# Images for Robert Peel downloaded successfully.
# Downloading images for subject: Samit Patel
# This is 1 image for Samit Patel
# This is 2 image for Samit Patel
# This is 3 image for Samit Patel
# This is 4 image for Samit Patel
# This is 5 image for Samit Patel
# Images for Samit Patel downloaded successfully.
# Downloading images for subject: Russian Empire
# This is 1 image for Russian Empire
# This is 2 image for Russian Empire
# This is 3 image for Russian Empire
# This is 4 image for Russian Empire
# This is 5 image for Russian Empire
# Images for Russian Empire downloaded successfully.
# Downloading images for subject: Eccellenza Lazio
# This is 1 image for Eccellenza Lazio
# This is 2 image for Eccellenza Lazio
# This is 3 image for Eccellenza Lazio
# This is 4 image for Eccellenza Lazio
# This is 5 image for Eccellenza Lazio
# Images for Eccellenza Lazio downloaded successfully.
# Downloading images for subject: Israel Football Association
# This is 1 image for Israel Football Association
# This is 2 image for Israel Football Association
# This is 3 image for Israel Football Association
# This is 4 image for Israel Football Association
# This is 5 image for Israel Football Association
# Images for Israel Football Association downloaded successfully.
# Downloading images for subject: William Wilson Corcoran
# This is 1 image for William Wilson Corcoran
# This is 2 image for William Wilson Corcoran
# This is 3 image for William Wilson Corcoran
# This is 4 image for William Wilson Corcoran
# This is 5 image for William Wilson Corcoran
# Images for William Wilson Corcoran downloaded successfully.
# Downloading images for subject: Shanghai United F.C.
# This is 1 image for Shanghai United F.C.
# This is 2 image for Shanghai United F.C.
# This is 3 image for Shanghai United F.C.
# This is 4 image for Shanghai United F.C.
# This is 5 image for Shanghai United F.C.
# Images for Shanghai United F.C. downloaded successfully.
# Downloading images for subject: Soulive
# This is 1 image for Soulive
# This is 2 image for Soulive
# This is 3 image for Soulive
# This is 4 image for Soulive
# This is 5 image for Soulive
# Images for Soulive downloaded successfully.
# Downloading images for subject: Yesterday
# This is 1 image for Yesterday
# This is 2 image for Yesterday
# This is 3 image for Yesterday
# This is 4 image for Yesterday
# This is 5 image for Yesterday
# Images for Yesterday downloaded successfully.
# Downloading images for subject: Françoise Mouly
# This is 1 image for Françoise Mouly
# This is 2 image for Françoise Mouly
# This is 3 image for Françoise Mouly
# This is 4 image for Françoise Mouly
# This is 5 image for Françoise Mouly
# Images for Françoise Mouly downloaded successfully.
# Downloading images for subject: Ford Super Duty
# This is 1 image for Ford Super Duty
# This is 2 image for Ford Super Duty
# This is 3 image for Ford Super Duty
# This is 4 image for Ford Super Duty
# This is 5 image for Ford Super Duty
# Images for Ford Super Duty downloaded successfully.
# Downloading images for subject: Tim Berners-Lee
# This is 1 image for Tim Berners-Lee
# This is 2 image for Tim Berners-Lee
# This is 3 image for Tim Berners-Lee
# This is 4 image for Tim Berners-Lee
# This is 5 image for Tim Berners-Lee
# Images for Tim Berners-Lee downloaded successfully.
# Downloading images for subject: Belfast Celtic F.C.
# This is 1 image for Belfast Celtic F.C.
# This is 2 image for Belfast Celtic F.C.
# This is 3 image for Belfast Celtic F.C.
# This is 4 image for Belfast Celtic F.C.
# This is 5 image for Belfast Celtic F.C.
# Images for Belfast Celtic F.C. downloaded successfully.
# Downloading images for subject: Barry Larkin
# This is 1 image for Barry Larkin
# This is 2 image for Barry Larkin
# This is 3 image for Barry Larkin
# This is 4 image for Barry Larkin
# This is 5 image for Barry Larkin
# Images for Barry Larkin downloaded successfully.
# Downloading images for subject: The Illustrated Man
# This is 1 image for The Illustrated Man
# This is 2 image for The Illustrated Man
# This is 3 image for The Illustrated Man
# This is 4 image for The Illustrated Man
# This is 5 image for The Illustrated Man
# Images for The Illustrated Man downloaded successfully.
# Downloading images for subject: Louis XV of France
# This is 1 image for Louis XV of France
# This is 2 image for Louis XV of France
# This is 3 image for Louis XV of France
# This is 4 image for Louis XV of France
# This is 5 image for Louis XV of France
# Images for Louis XV of France downloaded successfully.
# Downloading images for subject: Nigeria Football Federation
# This is 1 image for Nigeria Football Federation
# This is 2 image for Nigeria Football Federation
# This is 3 image for Nigeria Football Federation
# This is 4 image for Nigeria Football Federation
# This is 5 image for Nigeria Football Federation
# Images for Nigeria Football Federation downloaded successfully.
# Downloading images for subject: 2009 World Series
# This is 1 image for 2009 World Series
# This is 2 image for 2009 World Series
# This is 3 image for 2009 World Series
# This is 4 image for 2009 World Series
# This is 5 image for 2009 World Series
# Images for 2009 World Series downloaded successfully.
# Downloading images for subject: 2011 AFC Champions League
# This is 1 image for 2011 AFC Champions League
# This is 2 image for 2011 AFC Champions League
# This is 3 image for 2011 AFC Champions League
# This is 4 image for 2011 AFC Champions League
# This is 5 image for 2011 AFC Champions League
# Images for 2011 AFC Champions League downloaded successfully.
# Downloading images for subject: Olga Knipper
# This is 1 image for Olga Knipper
# This is 2 image for Olga Knipper
# This is 3 image for Olga Knipper
# This is 4 image for Olga Knipper
# This is 5 image for Olga Knipper
# Images for Olga Knipper downloaded successfully.
# Downloading images for subject: Taylor Swift
# This is 1 image for Taylor Swift
# This is 2 image for Taylor Swift
# This is 3 image for Taylor Swift
# This is 4 image for Taylor Swift
# This is 5 image for Taylor Swift
# Images for Taylor Swift downloaded successfully.
# Downloading images for subject: 1959 FA Cup Final
# This is 1 image for 1959 FA Cup Final
# This is 2 image for 1959 FA Cup Final
# This is 3 image for 1959 FA Cup Final
# This is 4 image for 1959 FA Cup Final
# This is 5 image for 1959 FA Cup Final
# Images for 1959 FA Cup Final downloaded successfully.
# Downloading images for subject: Terry Nation
# This is 1 image for Terry Nation
# This is 2 image for Terry Nation
# This is 3 image for Terry Nation
# This is 4 image for Terry Nation
# This is 5 image for Terry Nation
# Images for Terry Nation downloaded successfully.
# Downloading images for subject: Internet Information Services
# This is 1 image for Internet Information Services
# This is 2 image for Internet Information Services
# This is 3 image for Internet Information Services
# This is 4 image for Internet Information Services
# This is 5 image for Internet Information Services
# Images for Internet Information Services downloaded successfully.
# Downloading images for subject: James Brolin
# This is 1 image for James Brolin
# This is 2 image for James Brolin
# This is 3 image for James Brolin
# This is 4 image for James Brolin
# This is 5 image for James Brolin
# Images for James Brolin downloaded successfully.
# Downloading images for subject: Kenny Britt
# This is 1 image for Kenny Britt
# This is 2 image for Kenny Britt
# This is 3 image for Kenny Britt
# This is 4 image for Kenny Britt
# This is 5 image for Kenny Britt
# Images for Kenny Britt downloaded successfully.
# Downloading images for subject: Paul II
# This is 1 image for Paul II
# This is 2 image for Paul II
# This is 3 image for Paul II
# This is 4 image for Paul II
# This is 5 image for Paul II
# Images for Paul II downloaded successfully.
# Downloading images for subject: Congolese Party of Labour
# This is 1 image for Congolese Party of Labour
# This is 2 image for Congolese Party of Labour
# This is 3 image for Congolese Party of Labour
# This is 4 image for Congolese Party of Labour
# This is 5 image for Congolese Party of Labour
# Images for Congolese Party of Labour downloaded successfully.
# Downloading images for subject: Robert Moog
# This is 1 image for Robert Moog
# This is 2 image for Robert Moog
# This is 3 image for Robert Moog
# This is 4 image for Robert Moog
# This is 5 image for Robert Moog
# Images for Robert Moog downloaded successfully.
# Downloading images for subject: Tyronn Lue
# This is 1 image for Tyronn Lue
# This is 2 image for Tyronn Lue
# This is 3 image for Tyronn Lue
# This is 4 image for Tyronn Lue
# This is 5 image for Tyronn Lue
# Images for Tyronn Lue downloaded successfully.
# Downloading images for subject: Macbeth
# This is 1 image for Macbeth
# This is 2 image for Macbeth
# This is 3 image for Macbeth
# This is 4 image for Macbeth
# This is 5 image for Macbeth
# Images for Macbeth downloaded successfully.
# Downloading images for subject: The Wall
# This is 1 image for The Wall
# This is 2 image for The Wall
# This is 3 image for The Wall
# This is 4 image for The Wall
# This is 5 image for The Wall
# Images for The Wall downloaded successfully.
# Downloading images for subject: Carl Menger
# This is 1 image for Carl Menger
# This is 2 image for Carl Menger
# This is 3 image for Carl Menger
# This is 4 image for Carl Menger
# This is 5 image for Carl Menger
# Images for Carl Menger downloaded successfully.
# Downloading images for subject: Amanda Palmer
# This is 1 image for Amanda Palmer
# This is 2 image for Amanda Palmer
# This is 3 image for Amanda Palmer
# This is 4 image for Amanda Palmer
# This is 5 image for Amanda Palmer
# Images for Amanda Palmer downloaded successfully.
# Downloading images for subject: Canadian Broadcasting Corporation
# This is 1 image for Canadian Broadcasting Corporation
# This is 2 image for Canadian Broadcasting Corporation
# This is 3 image for Canadian Broadcasting Corporation
# This is 4 image for Canadian Broadcasting Corporation
# This is 5 image for Canadian Broadcasting Corporation
# Images for Canadian Broadcasting Corporation downloaded successfully.
# Downloading images for subject: Harper Lee
# This is 1 image for Harper Lee
# This is 2 image for Harper Lee
# This is 3 image for Harper Lee
# This is 4 image for Harper Lee
# This is 5 image for Harper Lee
# Images for Harper Lee downloaded successfully.
# Downloading images for subject: Southern Pacific
# This is 1 image for Southern Pacific
# This is 2 image for Southern Pacific
# This is 3 image for Southern Pacific
# This is 4 image for Southern Pacific
# This is 5 image for Southern Pacific
# Images for Southern Pacific downloaded successfully.
# Downloading images for subject: Slaughterhouse-Five
# This is 1 image for Slaughterhouse-Five
# This is 2 image for Slaughterhouse-Five
# This is 3 image for Slaughterhouse-Five
# This is 4 image for Slaughterhouse-Five
# This is 5 image for Slaughterhouse-Five
# Images for Slaughterhouse-Five downloaded successfully.
# Downloading images for subject: RZA
# This is 1 image for RZA
# This is 2 image for RZA
# This is 3 image for RZA
# This is 4 image for RZA
# This is 5 image for RZA
# Images for RZA downloaded successfully.
# Downloading images for subject: Ford Sierra RS Cosworth
# This is 1 image for Ford Sierra RS Cosworth
# This is 2 image for Ford Sierra RS Cosworth
# This is 3 image for Ford Sierra RS Cosworth
# This is 4 image for Ford Sierra RS Cosworth
# This is 5 image for Ford Sierra RS Cosworth
# Images for Ford Sierra RS Cosworth downloaded successfully.
# Downloading images for subject: Carmarthen Town A.F.C.
# This is 1 image for Carmarthen Town A.F.C.
# This is 2 image for Carmarthen Town A.F.C.
# This is 3 image for Carmarthen Town A.F.C.
# This is 4 image for Carmarthen Town A.F.C.
# This is 5 image for Carmarthen Town A.F.C.
# Images for Carmarthen Town A.F.C. downloaded successfully.
# Downloading images for subject: Mark Millar
# This is 1 image for Mark Millar
# This is 2 image for Mark Millar
# This is 3 image for Mark Millar
# This is 4 image for Mark Millar
# This is 5 image for Mark Millar
# Images for Mark Millar downloaded successfully.
# Downloading images for subject: bhikkhu
# This is 1 image for bhikkhu
# This is 2 image for bhikkhu
# This is 3 image for bhikkhu
# This is 4 image for bhikkhu
# This is 5 image for bhikkhu
# Images for bhikkhu downloaded successfully.
# Downloading images for subject: Hotline Bling
# This is 1 image for Hotline Bling
# This is 2 image for Hotline Bling
# This is 3 image for Hotline Bling
# This is 4 image for Hotline Bling
# This is 5 image for Hotline Bling
# Images for Hotline Bling downloaded successfully.
# Downloading images for subject: Wardell Gray
# This is 1 image for Wardell Gray
# This is 2 image for Wardell Gray
# This is 3 image for Wardell Gray
# This is 4 image for Wardell Gray
# This is 5 image for Wardell Gray
# Images for Wardell Gray downloaded successfully.
# Downloading images for subject: Liga IV
# This is 1 image for Liga IV
# This is 2 image for Liga IV
# This is 3 image for Liga IV
# This is 4 image for Liga IV
# This is 5 image for Liga IV
# Images for Liga IV downloaded successfully.
# Downloading images for subject: Within You Without You
# This is 1 image for Within You Without You
# This is 2 image for Within You Without You
# This is 3 image for Within You Without You
# This is 4 image for Within You Without You
# This is 5 image for Within You Without You
# Images for Within You Without You downloaded successfully.
# Downloading images for subject: Jean de Brébeuf
# This is 1 image for Jean de Brébeuf
# This is 2 image for Jean de Brébeuf
# This is 3 image for Jean de Brébeuf
# This is 4 image for Jean de Brébeuf
# This is 5 image for Jean de Brébeuf
# Images for Jean de Brébeuf downloaded successfully.
# Downloading images for subject: Bryce Harper
# This is 1 image for Bryce Harper
# This is 2 image for Bryce Harper
# This is 3 image for Bryce Harper
# This is 4 image for Bryce Harper
# This is 5 image for Bryce Harper
# Images for Bryce Harper downloaded successfully.
# Downloading images for subject: Silicon Valley
# This is 1 image for Silicon Valley
# This is 2 image for Silicon Valley
# This is 3 image for Silicon Valley
# This is 4 image for Silicon Valley
# This is 5 image for Silicon Valley
# Images for Silicon Valley downloaded successfully.
# Downloading images for subject: York University
# This is 1 image for York University
# This is 2 image for York University
# This is 3 image for York University
# This is 4 image for York University
# This is 5 image for York University
# Images for York University downloaded successfully.
# Downloading images for subject: Sheikh Jamal Dhanmondi Club
# This is 1 image for Sheikh Jamal Dhanmondi Club
# This is 2 image for Sheikh Jamal Dhanmondi Club
# This is 3 image for Sheikh Jamal Dhanmondi Club
# This is 4 image for Sheikh Jamal Dhanmondi Club
# This is 5 image for Sheikh Jamal Dhanmondi Club
# Images for Sheikh Jamal Dhanmondi Club downloaded successfully.
# Downloading images for subject: Birdie Tebbetts
# This is 1 image for Birdie Tebbetts
# This is 2 image for Birdie Tebbetts
# This is 3 image for Birdie Tebbetts
# This is 4 image for Birdie Tebbetts
# This is 5 image for Birdie Tebbetts
# Images for Birdie Tebbetts downloaded successfully.
# Downloading images for subject: Satyricon
# This is 1 image for Satyricon
# This is 2 image for Satyricon
# This is 3 image for Satyricon
# This is 4 image for Satyricon
# This is 5 image for Satyricon
# Images for Satyricon downloaded successfully.
# Downloading images for subject: Michael Patrick Carroll
# This is 1 image for Michael Patrick Carroll
# This is 2 image for Michael Patrick Carroll
# This is 3 image for Michael Patrick Carroll
# This is 4 image for Michael Patrick Carroll
# This is 5 image for Michael Patrick Carroll
# Images for Michael Patrick Carroll downloaded successfully.
# Downloading images for subject: Mixu Paatelainen
# This is 1 image for Mixu Paatelainen
# This is 2 image for Mixu Paatelainen
# This is 3 image for Mixu Paatelainen
# This is 4 image for Mixu Paatelainen
# This is 5 image for Mixu Paatelainen
# Images for Mixu Paatelainen downloaded successfully.
# Downloading images for subject: Laurent Koscielny
# This is 1 image for Laurent Koscielny
# This is 2 image for Laurent Koscielny
# This is 3 image for Laurent Koscielny
# This is 4 image for Laurent Koscielny
# This is 5 image for Laurent Koscielny
# Images for Laurent Koscielny downloaded successfully.
# Downloading images for subject: Sue Bird
# This is 1 image for Sue Bird
# This is 2 image for Sue Bird
# This is 3 image for Sue Bird
# This is 4 image for Sue Bird
# This is 5 image for Sue Bird
# Images for Sue Bird downloaded successfully.
# Downloading images for subject: University of Chile
# This is 1 image for University of Chile
# This is 2 image for University of Chile
# This is 3 image for University of Chile
# This is 4 image for University of Chile
# This is 5 image for University of Chile
# Images for University of Chile downloaded successfully.
# Downloading images for subject: Juan Antonio Samaranch
# This is 1 image for Juan Antonio Samaranch
# This is 2 image for Juan Antonio Samaranch
# This is 3 image for Juan Antonio Samaranch
# This is 4 image for Juan Antonio Samaranch
# This is 5 image for Juan Antonio Samaranch
# Images for Juan Antonio Samaranch downloaded successfully.
# Downloading images for subject: Mildred Bailey
# This is 1 image for Mildred Bailey
# This is 2 image for Mildred Bailey
# This is 3 image for Mildred Bailey
# This is 4 image for Mildred Bailey
# This is 5 image for Mildred Bailey
# Images for Mildred Bailey downloaded successfully.
# Downloading images for subject: Bandai Namco Entertainment
# This is 1 image for Bandai Namco Entertainment
# This is 2 image for Bandai Namco Entertainment
# This is 3 image for Bandai Namco Entertainment
# This is 4 image for Bandai Namco Entertainment
# This is 5 image for Bandai Namco Entertainment
# Images for Bandai Namco Entertainment downloaded successfully.
# Downloading images for subject: Esteban Cambiasso
# This is 1 image for Esteban Cambiasso
# This is 2 image for Esteban Cambiasso
# This is 3 image for Esteban Cambiasso
# This is 4 image for Esteban Cambiasso
# This is 5 image for Esteban Cambiasso
# Images for Esteban Cambiasso downloaded successfully.
# Downloading images for subject: Kingdom of England
# This is 1 image for Kingdom of England
# This is 2 image for Kingdom of England
# This is 3 image for Kingdom of England
# This is 4 image for Kingdom of England
# This is 5 image for Kingdom of England
# Images for Kingdom of England downloaded successfully.
# Downloading images for subject: Zorba the Greek
# This is 1 image for Zorba the Greek
# This is 2 image for Zorba the Greek
# This is 3 image for Zorba the Greek
# This is 4 image for Zorba the Greek
# This is 5 image for Zorba the Greek
# Images for Zorba the Greek downloaded successfully.
# Downloading images for subject: Ethiopian Football Federation
# This is 1 image for Ethiopian Football Federation
# This is 2 image for Ethiopian Football Federation
# This is 3 image for Ethiopian Football Federation
# This is 4 image for Ethiopian Football Federation
# This is 5 image for Ethiopian Football Federation
# Images for Ethiopian Football Federation downloaded successfully.
# Downloading images for subject: Ricky Rubio
# This is 1 image for Ricky Rubio
# This is 2 image for Ricky Rubio
# This is 3 image for Ricky Rubio
# This is 4 image for Ricky Rubio
# This is 5 image for Ricky Rubio
# Images for Ricky Rubio downloaded successfully.
# Downloading images for subject: Crisis on Infinite Earths
# This is 1 image for Crisis on Infinite Earths
# This is 2 image for Crisis on Infinite Earths
# This is 3 image for Crisis on Infinite Earths
# This is 4 image for Crisis on Infinite Earths
# This is 5 image for Crisis on Infinite Earths
# Images for Crisis on Infinite Earths downloaded successfully.
# Downloading images for subject: George Harrison
# This is 1 image for George Harrison
# This is 2 image for George Harrison
# This is 3 image for George Harrison
# This is 4 image for George Harrison
# This is 5 image for George Harrison
# Images for George Harrison downloaded successfully.
# Downloading images for subject: Raúl Alfonsín
# This is 1 image for Raúl Alfonsín
# This is 2 image for Raúl Alfonsín
# This is 3 image for Raúl Alfonsín
# This is 4 image for Raúl Alfonsín
# This is 5 image for Raúl Alfonsín
# Images for Raúl Alfonsín downloaded successfully.
# Downloading images for subject: The Rookies
# This is 1 image for The Rookies
# This is 2 image for The Rookies
# This is 3 image for The Rookies
# This is 4 image for The Rookies
# This is 5 image for The Rookies
# Images for The Rookies downloaded successfully.
# Downloading images for subject: Ozzy Osbourne
# This is 1 image for Ozzy Osbourne
# This is 2 image for Ozzy Osbourne
# This is 3 image for Ozzy Osbourne
# This is 4 image for Ozzy Osbourne
# This is 5 image for Ozzy Osbourne
# Images for Ozzy Osbourne downloaded successfully.
# Downloading images for subject: Kyle Reese
# This is 1 image for Kyle Reese
# This is 2 image for Kyle Reese
# This is 3 image for Kyle Reese
# This is 4 image for Kyle Reese
# This is 5 image for Kyle Reese
# Images for Kyle Reese downloaded successfully.
# Downloading images for subject: Darrell Porter
# This is 1 image for Darrell Porter
# This is 2 image for Darrell Porter
# This is 3 image for Darrell Porter
# This is 4 image for Darrell Porter
# This is 5 image for Darrell Porter
# Images for Darrell Porter downloaded successfully.
# Downloading images for subject: True Detective
# This is 1 image for True Detective
# This is 2 image for True Detective
# This is 3 image for True Detective
# This is 4 image for True Detective
# This is 5 image for True Detective
# Images for True Detective downloaded successfully.
# Downloading images for subject: Outlook Express
# This is 1 image for Outlook Express
# This is 2 image for Outlook Express
# This is 3 image for Outlook Express
# This is 4 image for Outlook Express
# This is 5 image for Outlook Express
# Images for Outlook Express downloaded successfully.
# Downloading images for subject: Dina Meyer
# This is 1 image for Dina Meyer
# This is 2 image for Dina Meyer
# This is 3 image for Dina Meyer
# This is 4 image for Dina Meyer
# This is 5 image for Dina Meyer
# Images for Dina Meyer downloaded successfully.
# Downloading images for subject: Arthur Guinness
# This is 1 image for Arthur Guinness
# This is 2 image for Arthur Guinness
# This is 3 image for Arthur Guinness
# This is 4 image for Arthur Guinness
# This is 5 image for Arthur Guinness
# Images for Arthur Guinness downloaded successfully.
# Downloading images for subject: Muggsy Bogues
# This is 1 image for Muggsy Bogues
# This is 2 image for Muggsy Bogues
# This is 3 image for Muggsy Bogues
# This is 4 image for Muggsy Bogues
# This is 5 image for Muggsy Bogues
# Images for Muggsy Bogues downloaded successfully.
# Downloading images for subject: funk
# This is 1 image for funk
# This is 2 image for funk
# This is 3 image for funk
# This is 4 image for funk
# This is 5 image for funk
# Images for funk downloaded successfully.
# Downloading images for subject: Screen International
# This is 1 image for Screen International
# This is 2 image for Screen International
# This is 3 image for Screen International
# This is 4 image for Screen International
# This is 5 image for Screen International
# Images for Screen International downloaded successfully.
# Downloading images for subject: Blizzard of Ozz
# This is 1 image for Blizzard of Ozz
# This is 2 image for Blizzard of Ozz
# This is 3 image for Blizzard of Ozz
# This is 4 image for Blizzard of Ozz
# This is 5 image for Blizzard of Ozz
# Images for Blizzard of Ozz downloaded successfully.
# Downloading images for subject: Ball Four
# This is 1 image for Ball Four
# This is 2 image for Ball Four
# This is 3 image for Ball Four
# This is 4 image for Ball Four
# This is 5 image for Ball Four
# Images for Ball Four downloaded successfully.
# Downloading images for subject: Jayavarman II
# This is 1 image for Jayavarman II
# This is 2 image for Jayavarman II
# This is 3 image for Jayavarman II
# This is 4 image for Jayavarman II
# This is 5 image for Jayavarman II
# Images for Jayavarman II downloaded successfully.
# Downloading images for subject: Ernest Renan
# This is 1 image for Ernest Renan
# This is 2 image for Ernest Renan
# This is 3 image for Ernest Renan
# This is 4 image for Ernest Renan
# This is 5 image for Ernest Renan
# Images for Ernest Renan downloaded successfully.
# Downloading images for subject: Ecumenical Patriarch of Constantinople
# This is 1 image for Ecumenical Patriarch of Constantinople
# This is 2 image for Ecumenical Patriarch of Constantinople
# This is 3 image for Ecumenical Patriarch of Constantinople
# This is 4 image for Ecumenical Patriarch of Constantinople
# This is 5 image for Ecumenical Patriarch of Constantinople
# Images for Ecumenical Patriarch of Constantinople downloaded successfully.
# Downloading images for subject: Ernst Stavro Blofeld
# This is 1 image for Ernst Stavro Blofeld
# This is 2 image for Ernst Stavro Blofeld
# This is 3 image for Ernst Stavro Blofeld
# This is 4 image for Ernst Stavro Blofeld
# This is 5 image for Ernst Stavro Blofeld
# Images for Ernst Stavro Blofeld downloaded successfully.
# Downloading images for subject: Jacqueline Kennedy Onassis
# This is 1 image for Jacqueline Kennedy Onassis
# This is 2 image for Jacqueline Kennedy Onassis
# This is 3 image for Jacqueline Kennedy Onassis
# This is 4 image for Jacqueline Kennedy Onassis
# This is 5 image for Jacqueline Kennedy Onassis
# Images for Jacqueline Kennedy Onassis downloaded successfully.
# Downloading images for subject: Rutan Voyager
# This is 1 image for Rutan Voyager
# This is 2 image for Rutan Voyager
# This is 3 image for Rutan Voyager
# This is 4 image for Rutan Voyager
# This is 5 image for Rutan Voyager
# Images for Rutan Voyager downloaded successfully.
# Downloading images for subject: John C. Stennis
# This is 1 image for John C. Stennis
# This is 2 image for John C. Stennis
# This is 3 image for John C. Stennis
# This is 4 image for John C. Stennis
# This is 5 image for John C. Stennis
# Images for John C. Stennis downloaded successfully.
# Downloading images for subject: Kim Basinger
# This is 1 image for Kim Basinger
# This is 2 image for Kim Basinger
# This is 3 image for Kim Basinger
# This is 4 image for Kim Basinger
# This is 5 image for Kim Basinger
# Images for Kim Basinger downloaded successfully.
# Downloading images for subject: Robert Goulet
# This is 1 image for Robert Goulet
# This is 2 image for Robert Goulet
# This is 3 image for Robert Goulet
# This is 4 image for Robert Goulet
# This is 5 image for Robert Goulet
# Images for Robert Goulet downloaded successfully.
# Downloading images for subject: Vladimir Lenin
# This is 1 image for Vladimir Lenin
# This is 2 image for Vladimir Lenin
# This is 3 image for Vladimir Lenin
# This is 4 image for Vladimir Lenin
# This is 5 image for Vladimir Lenin
# Images for Vladimir Lenin downloaded successfully.
# Downloading images for subject: Jon Krakauer
# This is 1 image for Jon Krakauer
# This is 2 image for Jon Krakauer
# This is 3 image for Jon Krakauer
# This is 4 image for Jon Krakauer
# This is 5 image for Jon Krakauer
# Images for Jon Krakauer downloaded successfully.
# Downloading images for subject: Jesualdo Ferreira
# This is 1 image for Jesualdo Ferreira
# This is 2 image for Jesualdo Ferreira
# This is 3 image for Jesualdo Ferreira
# This is 4 image for Jesualdo Ferreira
# This is 5 image for Jesualdo Ferreira
# Images for Jesualdo Ferreira downloaded successfully.
# Downloading images for subject: The Tempest
# This is 1 image for The Tempest
# This is 2 image for The Tempest
# This is 3 image for The Tempest
# This is 4 image for The Tempest
# This is 5 image for The Tempest
# Images for The Tempest downloaded successfully.
# Downloading images for subject: Rafael van der Vaart
# This is 1 image for Rafael van der Vaart
# This is 2 image for Rafael van der Vaart
# This is 3 image for Rafael van der Vaart
# This is 4 image for Rafael van der Vaart
# This is 5 image for Rafael van der Vaart
# Images for Rafael van der Vaart downloaded successfully.
# Downloading images for subject: Asa Hutchinson
# This is 1 image for Asa Hutchinson
# This is 2 image for Asa Hutchinson
# This is 3 image for Asa Hutchinson
# This is 4 image for Asa Hutchinson
# This is 5 image for Asa Hutchinson
# Images for Asa Hutchinson downloaded successfully.
# Downloading images for subject: Jacques Perrin
# This is 1 image for Jacques Perrin
# This is 2 image for Jacques Perrin
# This is 3 image for Jacques Perrin
# This is 4 image for Jacques Perrin
# This is 5 image for Jacques Perrin
# Images for Jacques Perrin downloaded successfully.
# Downloading images for subject: Boston
# This is 1 image for Boston
# This is 2 image for Boston
# This is 3 image for Boston
# This is 4 image for Boston
# This is 5 image for Boston
# Images for Boston downloaded successfully.
# Downloading images for subject: Ford GT
# This is 1 image for Ford GT
# This is 2 image for Ford GT
# This is 3 image for Ford GT
# This is 4 image for Ford GT
# This is 5 image for Ford GT
# Images for Ford GT downloaded successfully.
# Downloading images for subject: Andrew Bynum
# This is 1 image for Andrew Bynum
# This is 2 image for Andrew Bynum
# This is 3 image for Andrew Bynum
# This is 4 image for Andrew Bynum
# This is 5 image for Andrew Bynum
# Images for Andrew Bynum downloaded successfully.
# Downloading images for subject: Dietrich Mateschitz
# This is 1 image for Dietrich Mateschitz
# This is 2 image for Dietrich Mateschitz
# This is 3 image for Dietrich Mateschitz
# This is 4 image for Dietrich Mateschitz
# This is 5 image for Dietrich Mateschitz
# Images for Dietrich Mateschitz downloaded successfully.
# Downloading images for subject: Georges Simenon
# This is 1 image for Georges Simenon
# This is 2 image for Georges Simenon
# This is 3 image for Georges Simenon
# This is 4 image for Georges Simenon
# This is 5 image for Georges Simenon
# Images for Georges Simenon downloaded successfully.
# Downloading images for subject: James Middleton Cox
# This is 1 image for James Middleton Cox
# This is 2 image for James Middleton Cox
# This is 3 image for James Middleton Cox
# This is 4 image for James Middleton Cox
# This is 5 image for James Middleton Cox
# Images for James Middleton Cox downloaded successfully.
# Downloading images for subject: New York Yankees
# This is 1 image for New York Yankees
# This is 2 image for New York Yankees
# This is 3 image for New York Yankees
# This is 4 image for New York Yankees
# This is 5 image for New York Yankees
# Images for New York Yankees downloaded successfully.
# Downloading images for subject: Harry Kendall Thaw
# This is 1 image for Harry Kendall Thaw
# This is 2 image for Harry Kendall Thaw
# This is 3 image for Harry Kendall Thaw
# This is 4 image for Harry Kendall Thaw
# This is 5 image for Harry Kendall Thaw
# Images for Harry Kendall Thaw downloaded successfully.
# Downloading images for subject: George Weiss
# This is 1 image for George Weiss
# This is 2 image for George Weiss
# This is 3 image for George Weiss
# This is 4 image for George Weiss
# This is 5 image for George Weiss
# Images for George Weiss downloaded successfully.
# Downloading images for subject: German Empire
# This is 1 image for German Empire
# This is 2 image for German Empire
# This is 3 image for German Empire
# This is 4 image for German Empire
# This is 5 image for German Empire
# Images for German Empire downloaded successfully.
# Downloading images for subject: Forza Italia
# This is 1 image for Forza Italia
# This is 2 image for Forza Italia
# This is 3 image for Forza Italia
# This is 4 image for Forza Italia
# This is 5 image for Forza Italia
# Images for Forza Italia downloaded successfully.
# Downloading images for subject: The Dark Knight Returns
# This is 1 image for The Dark Knight Returns
# This is 2 image for The Dark Knight Returns
# This is 3 image for The Dark Knight Returns
# This is 4 image for The Dark Knight Returns
# This is 5 image for The Dark Knight Returns
# Images for The Dark Knight Returns downloaded successfully.
# Downloading images for subject: Mathias Grünewald
# This is 1 image for Mathias Grünewald
# This is 2 image for Mathias Grünewald
# This is 3 image for Mathias Grünewald
# This is 4 image for Mathias Grünewald
# This is 5 image for Mathias Grünewald
# Images for Mathias Grünewald downloaded successfully.
# Downloading images for subject: University of Washington
# This is 1 image for University of Washington
# This is 2 image for University of Washington
# This is 3 image for University of Washington
# This is 4 image for University of Washington
# This is 5 image for University of Washington
# Images for University of Washington downloaded successfully.
# Downloading images for subject: Strawberry Fields Forever
# This is 1 image for Strawberry Fields Forever
# This is 2 image for Strawberry Fields Forever
# This is 3 image for Strawberry Fields Forever
# This is 4 image for Strawberry Fields Forever
# This is 5 image for Strawberry Fields Forever
# Images for Strawberry Fields Forever downloaded successfully.
# Downloading images for subject: Wildcats
# This is 1 image for Wildcats
# This is 2 image for Wildcats
# This is 3 image for Wildcats
# This is 4 image for Wildcats
# This is 5 image for Wildcats
# Images for Wildcats downloaded successfully.
# Downloading images for subject: Gorgias
# This is 1 image for Gorgias
# This is 2 image for Gorgias
# This is 3 image for Gorgias
# This is 4 image for Gorgias
# This is 5 image for Gorgias
# Images for Gorgias downloaded successfully.
# Downloading images for subject: 2011 Champions League Twenty20
# This is 1 image for 2011 Champions League Twenty20
# This is 2 image for 2011 Champions League Twenty20
# This is 3 image for 2011 Champions League Twenty20
# This is 4 image for 2011 Champions League Twenty20
# This is 5 image for 2011 Champions League Twenty20
# Images for 2011 Champions League Twenty20 downloaded successfully.
# Downloading images for subject: Harvard University
# This is 1 image for Harvard University
# This is 2 image for Harvard University
# This is 3 image for Harvard University
# This is 4 image for Harvard University
# This is 5 image for Harvard University
# Images for Harvard University downloaded successfully.
# Downloading images for subject: Less Than Perfect
# This is 1 image for Less Than Perfect
# This is 2 image for Less Than Perfect
# This is 3 image for Less Than Perfect
# This is 4 image for Less Than Perfect
# This is 5 image for Less Than Perfect
# Images for Less Than Perfect downloaded successfully.
# Downloading images for subject: University of Calcutta
# This is 1 image for University of Calcutta
# This is 2 image for University of Calcutta
# This is 3 image for University of Calcutta
# This is 4 image for University of Calcutta
# This is 5 image for University of Calcutta
# Images for University of Calcutta downloaded successfully.
# Downloading images for subject: Addis Ababa Stadium
# This is 1 image for Addis Ababa Stadium
# This is 2 image for Addis Ababa Stadium
# This is 3 image for Addis Ababa Stadium
# This is 4 image for Addis Ababa Stadium
# This is 5 image for Addis Ababa Stadium
# Images for Addis Ababa Stadium downloaded successfully.
# Downloading images for subject: Vicente Padilla
# This is 1 image for Vicente Padilla
# This is 2 image for Vicente Padilla
# This is 3 image for Vicente Padilla
# This is 4 image for Vicente Padilla
# This is 5 image for Vicente Padilla
# Images for Vicente Padilla downloaded successfully.
# Downloading images for subject: University of Vienna
# This is 1 image for University of Vienna
# This is 2 image for University of Vienna
# This is 3 image for University of Vienna
# This is 4 image for University of Vienna
# This is 5 image for University of Vienna
# Images for University of Vienna downloaded successfully.
# Downloading images for subject: Abou Diaby
# This is 1 image for Abou Diaby
# This is 2 image for Abou Diaby
# This is 3 image for Abou Diaby
# This is 4 image for Abou Diaby
# This is 5 image for Abou Diaby
# Images for Abou Diaby downloaded successfully.
# Downloading images for subject: OGC Nice
# This is 1 image for OGC Nice
# This is 2 image for OGC Nice
# This is 3 image for OGC Nice
# This is 4 image for OGC Nice
# This is 5 image for OGC Nice
# Images for OGC Nice downloaded successfully.
# Downloading images for subject: Irréversible
# This is 1 image for Irréversible
# This is 2 image for Irréversible
# This is 3 image for Irréversible
# This is 4 image for Irréversible
# This is 5 image for Irréversible
# Images for Irréversible downloaded successfully.
# Downloading images for subject: Ed Bailey
# This is 1 image for Ed Bailey
# This is 2 image for Ed Bailey
# This is 3 image for Ed Bailey
# This is 4 image for Ed Bailey
# This is 5 image for Ed Bailey
# Images for Ed Bailey downloaded successfully.
# Downloading images for subject: Louis van Gaal
# This is 1 image for Louis van Gaal
# This is 2 image for Louis van Gaal
# This is 3 image for Louis van Gaal
# This is 4 image for Louis van Gaal
# This is 5 image for Louis van Gaal
# Images for Louis van Gaal downloaded successfully.
# Downloading images for subject: Chris Dodd
# This is 1 image for Chris Dodd
# This is 2 image for Chris Dodd
# This is 3 image for Chris Dodd
# This is 4 image for Chris Dodd
# This is 5 image for Chris Dodd
# Images for Chris Dodd downloaded successfully.
# Downloading images for subject: Bf 109
# This is 1 image for Bf 109
# This is 2 image for Bf 109
# This is 3 image for Bf 109
# This is 4 image for Bf 109
# This is 5 image for Bf 109
# Images for Bf 109 downloaded successfully.
# Downloading images for subject: Mortal Kombat X
# This is 1 image for Mortal Kombat X
# This is 2 image for Mortal Kombat X
# This is 3 image for Mortal Kombat X
# This is 4 image for Mortal Kombat X
# This is 5 image for Mortal Kombat X
# Images for Mortal Kombat X downloaded successfully.
# Downloading images for subject: Alessandra Stanley
# This is 1 image for Alessandra Stanley
# This is 2 image for Alessandra Stanley
# This is 3 image for Alessandra Stanley
# This is 4 image for Alessandra Stanley
# This is 5 image for Alessandra Stanley
# Images for Alessandra Stanley downloaded successfully.
# Downloading images for subject: placekicker
# This is 1 image for placekicker
# This is 2 image for placekicker
# This is 3 image for placekicker
# This is 4 image for placekicker
# This is 5 image for placekicker
# Images for placekicker downloaded successfully.
# Downloading images for subject: Quentin Roosevelt
# This is 1 image for Quentin Roosevelt
# This is 2 image for Quentin Roosevelt
# This is 3 image for Quentin Roosevelt
# This is 4 image for Quentin Roosevelt
# This is 5 image for Quentin Roosevelt
# Images for Quentin Roosevelt downloaded successfully.
# Downloading images for subject: Hummer H1
# This is 1 image for Hummer H1
# This is 2 image for Hummer H1
# This is 3 image for Hummer H1
# This is 4 image for Hummer H1
# This is 5 image for Hummer H1
# Images for Hummer H1 downloaded successfully.
# Downloading images for subject: Ralph Ellison
# This is 1 image for Ralph Ellison
# This is 2 image for Ralph Ellison
# This is 3 image for Ralph Ellison
# This is 4 image for Ralph Ellison
# This is 5 image for Ralph Ellison
# Images for Ralph Ellison downloaded successfully.
# Downloading images for subject: University of St. Thomas
# This is 1 image for University of St. Thomas
# This is 2 image for University of St. Thomas
# This is 3 image for University of St. Thomas
# This is 4 image for University of St. Thomas
# This is 5 image for University of St. Thomas
# Images for University of St. Thomas downloaded successfully.
# Downloading images for subject: Queen's Park F.C.
# This is 1 image for Queen's Park F.C.
# This is 2 image for Queen's Park F.C.
# This is 3 image for Queen's Park F.C.
# This is 4 image for Queen's Park F.C.
# This is 5 image for Queen's Park F.C.
# Images for Queen's Park F.C. downloaded successfully.
# Downloading images for subject: 1999 FIFA Confederations Cup
# This is 1 image for 1999 FIFA Confederations Cup
# This is 2 image for 1999 FIFA Confederations Cup
# This is 3 image for 1999 FIFA Confederations Cup
# This is 4 image for 1999 FIFA Confederations Cup
# This is 5 image for 1999 FIFA Confederations Cup
# Images for 1999 FIFA Confederations Cup downloaded successfully.
# Downloading images for subject: Benjamin Netanyahu
# This is 1 image for Benjamin Netanyahu
# This is 2 image for Benjamin Netanyahu
# This is 3 image for Benjamin Netanyahu
# This is 4 image for Benjamin Netanyahu
# This is 5 image for Benjamin Netanyahu
# Images for Benjamin Netanyahu downloaded successfully.
# Downloading images for subject: Jonas Valančiūnas
# This is 1 image for Jonas Valančiūnas
# This is 2 image for Jonas Valančiūnas
# This is 3 image for Jonas Valančiūnas
# This is 4 image for Jonas Valančiūnas
# This is 5 image for Jonas Valančiūnas
# Images for Jonas Valančiūnas downloaded successfully.
# Downloading images for subject: George Orwell
# This is 1 image for George Orwell
# This is 2 image for George Orwell
# This is 3 image for George Orwell
# This is 4 image for George Orwell
# This is 5 image for George Orwell
# Images for George Orwell downloaded successfully.
# Downloading images for subject: Martin Chuzzlewit
# This is 1 image for Martin Chuzzlewit
# This is 2 image for Martin Chuzzlewit
# This is 3 image for Martin Chuzzlewit
# This is 4 image for Martin Chuzzlewit
# This is 5 image for Martin Chuzzlewit
# Images for Martin Chuzzlewit downloaded successfully.
# Downloading images for subject: William Golding
# This is 1 image for William Golding
# This is 2 image for William Golding
# ...
# Downloading images for subject: El-P
# This is 1 image for El-P
# This is 2 image for El-P
# This is 3 image for El-P
# This is 4 image for El-P
# This is 5 image for El-P
# Images for El-P downloaded successfully.
# Downloading images for subject: Sporting Gijón
# This is 1 image for Sporting Gijón
# This is 2 image for Sporting Gijón
# This is 3 image for Sporting Gijón
# This is 4 image for Sporting Gijón
# This is 5 image for Sporting Gijón
# Images for Sporting Gijón downloaded successfully.
# Downloading images for subject: Bill Clinton
# This is 1 image for Bill Clinton
# This is 2 image for Bill Clinton
# This is 3 image for Bill Clinton
# This is 4 image for Bill Clinton
# This is 5 image for Bill Clinton
# Images for Bill Clinton downloaded successfully.
# Downloading images for subject: Shinji Kagawa
# This is 1 image for Shinji Kagawa
# This is 2 image for Shinji Kagawa
# This is 3 image for Shinji Kagawa
# This is 4 image for Shinji Kagawa
# This is 5 image for Shinji Kagawa
# Images for Shinji Kagawa downloaded successfully.
# Downloading images for subject: Rochdale A.F.C.
# This is 1 image for Rochdale A.F.C.
# This is 2 image for Rochdale A.F.C.
# This is 3 image for Rochdale A.F.C.
# This is 4 image for Rochdale A.F.C.
# This is 5 image for Rochdale A.F.C.
# Images for Rochdale A.F.C. downloaded successfully.
# Downloading images for subject: Windows Aero
# This is 1 image for Windows Aero
# This is 2 image for Windows Aero
# This is 3 image for Windows Aero
# This is 4 image for Windows Aero
# This is 5 image for Windows Aero
# Images for Windows Aero downloaded successfully.
# Downloading images for subject: Gary SouthShore RailCats
# This is 1 image for Gary SouthShore RailCats
# This is 2 image for Gary SouthShore RailCats
# This is 3 image for Gary SouthShore RailCats
# This is 4 image for Gary SouthShore RailCats
# This is 5 image for Gary SouthShore RailCats
# Images for Gary SouthShore RailCats downloaded successfully.
# Downloading images for subject: RIM-66 Standard MR
# This is 1 image for RIM-66 Standard MR
# This is 2 image for RIM-66 Standard MR
# This is 3 image for RIM-66 Standard MR
# This is 4 image for RIM-66 Standard MR
# This is 5 image for RIM-66 Standard MR
# Images for RIM-66 Standard MR downloaded successfully.
# Downloading images for subject: Prime Minister of Israel
# This is 1 image for Prime Minister of Israel
# This is 2 image for Prime Minister of Israel
# This is 3 image for Prime Minister of Israel
# This is 4 image for Prime Minister of Israel
# This is 5 image for Prime Minister of Israel
# Images for Prime Minister of Israel downloaded successfully.
# Downloading images for subject: The Trump Entrepreneur Initiative
# This is 1 image for The Trump Entrepreneur Initiative
# This is 2 image for The Trump Entrepreneur Initiative
# This is 3 image for The Trump Entrepreneur Initiative
# This is 4 image for The Trump Entrepreneur Initiative
# This is 5 image for The Trump Entrepreneur Initiative
# Images for The Trump Entrepreneur Initiative downloaded successfully.
# Downloading images for subject: Counter-Strike
# This is 1 image for Counter-Strike
# This is 2 image for Counter-Strike
# This is 3 image for Counter-Strike
# This is 4 image for Counter-Strike
# This is 5 image for Counter-Strike
# Images for Counter-Strike downloaded successfully.
# Downloading images for subject: Federico Fellini
# This is 1 image for Federico Fellini
# This is 2 image for Federico Fellini
# This is 3 image for Federico Fellini
# This is 4 image for Federico Fellini
# This is 5 image for Federico Fellini
# Images for Federico Fellini downloaded successfully.
# Downloading images for subject: Miley Cyrus
# This is 1 image for Miley Cyrus
# This is 2 image for Miley Cyrus
# This is 3 image for Miley Cyrus
# This is 4 image for Miley Cyrus
# This is 5 image for Miley Cyrus
# Images for Miley Cyrus downloaded successfully.
# Downloading images for subject: France
# This is 1 image for France
# This is 2 image for France
# This is 3 image for France
# This is 4 image for France
# This is 5 image for France
# Images for France downloaded successfully.
# Downloading images for subject: Vogue
# This is 1 image for Vogue
# This is 2 image for Vogue
# This is 3 image for Vogue
# This is 4 image for Vogue
# This is 5 image for Vogue
# Images for Vogue downloaded successfully.
# Downloading images for subject: Football Association of Wales
# This is 1 image for Football Association of Wales
# This is 2 image for Football Association of Wales
# This is 3 image for Football Association of Wales
# This is 4 image for Football Association of Wales
# This is 5 image for Football Association of Wales
# Images for Football Association of Wales downloaded successfully.
# Downloading images for subject: Iisalmi
# This is 1 image for Iisalmi
# This is 2 image for Iisalmi
# This is 3 image for Iisalmi
# This is 4 image for Iisalmi
# This is 5 image for Iisalmi
# Images for Iisalmi downloaded successfully.
# Downloading images for subject: John Steinbeck
# This is 1 image for John Steinbeck
# This is 2 image for John Steinbeck
# This is 3 image for John Steinbeck
# This is 4 image for John Steinbeck
# This is 5 image for John Steinbeck
# Images for John Steinbeck downloaded successfully.
# Downloading images for subject: Czech Republic
# This is 1 image for Czech Republic
# This is 2 image for Czech Republic
# This is 3 image for Czech Republic
# This is 4 image for Czech Republic
# This is 5 image for Czech Republic
# Images for Czech Republic downloaded successfully.
# Downloading images for subject: Martha Wayne
# This is 1 image for Martha Wayne
# This is 2 image for Martha Wayne
# This is 3 image for Martha Wayne
# This is 4 image for Martha Wayne
# This is 5 image for Martha Wayne
# Images for Martha Wayne downloaded successfully.
# Downloading images for subject: James Michael Curley
# This is 1 image for James Michael Curley
# This is 2 image for James Michael Curley
# This is 3 image for James Michael Curley
# This is 4 image for James Michael Curley
# This is 5 image for James Michael Curley
# Images for James Michael Curley downloaded successfully.
# Downloading images for subject: Pittsburgh Pirates
# This is 1 image for Pittsburgh Pirates
# This is 2 image for Pittsburgh Pirates
# This is 3 image for Pittsburgh Pirates
# This is 4 image for Pittsburgh Pirates
# This is 5 image for Pittsburgh Pirates
# Images for Pittsburgh Pirates downloaded successfully.
# Downloading images for subject: Lunds BK
# This is 1 image for Lunds BK
# This is 2 image for Lunds BK
# This is 3 image for Lunds BK
# This is 4 image for Lunds BK
# This is 5 image for Lunds BK
# Images for Lunds BK downloaded successfully.
# Downloading images for subject: Ars amatoria
# This is 1 image for Ars amatoria
# This is 2 image for Ars amatoria
# This is 3 image for Ars amatoria
# This is 4 image for Ars amatoria
# This is 5 image for Ars amatoria
# Images for Ars amatoria downloaded successfully.
# Downloading images for subject: Purification Rundown
# This is 1 image for Purification Rundown
# This is 2 image for Purification Rundown
# This is 3 image for Purification Rundown
# This is 4 image for Purification Rundown
# This is 5 image for Purification Rundown
# Images for Purification Rundown downloaded successfully.
# Downloading images for subject: Amit Shah
# This is 1 image for Amit Shah
# This is 2 image for Amit Shah
# This is 3 image for Amit Shah
# This is 4 image for Amit Shah
# This is 5 image for Amit Shah
# Images for Amit Shah downloaded successfully.
# Downloading images for subject: Tomorrow Never Knows
# This is 1 image for Tomorrow Never Knows
# This is 2 image for Tomorrow Never Knows
# This is 3 image for Tomorrow Never Knows
# This is 4 image for Tomorrow Never Knows
# This is 5 image for Tomorrow Never Knows
# Images for Tomorrow Never Knows downloaded successfully.
# Downloading images for subject: Catelyn Stark
# This is 1 image for Catelyn Stark
# This is 2 image for Catelyn Stark
# This is 3 image for Catelyn Stark
# This is 4 image for Catelyn Stark
# This is 5 image for Catelyn Stark
# Images for Catelyn Stark downloaded successfully.
# Downloading images for subject: Animal Liberation
# This is 1 image for Animal Liberation
# This is 2 image for Animal Liberation
# This is 3 image for Animal Liberation
# This is 4 image for Animal Liberation
# This is 5 image for Animal Liberation
# Images for Animal Liberation downloaded successfully.
# Downloading images for subject: Giordano Bruno
# This is 1 image for Giordano Bruno
# This is 2 image for Giordano Bruno
# This is 3 image for Giordano Bruno
# This is 4 image for Giordano Bruno
# This is 5 image for Giordano Bruno
# Images for Giordano Bruno downloaded successfully.
# Downloading images for subject: FC Andorra
# This is 1 image for FC Andorra
# This is 2 image for FC Andorra
# This is 3 image for FC Andorra
# This is 4 image for FC Andorra
# This is 5 image for FC Andorra
# Images for FC Andorra downloaded successfully.
# Downloading images for subject: Kingdom of Ireland
# This is 1 image for Kingdom of Ireland
# This is 2 image for Kingdom of Ireland
# This is 3 image for Kingdom of Ireland
# This is 4 image for Kingdom of Ireland
# This is 5 image for Kingdom of Ireland
# Images for Kingdom of Ireland downloaded successfully.
# Downloading images for subject: Thomas Hardy
# This is 1 image for Thomas Hardy
# This is 2 image for Thomas Hardy
# This is 3 image for Thomas Hardy
# This is 4 image for Thomas Hardy
# This is 5 image for Thomas Hardy
# Images for Thomas Hardy downloaded successfully.
# Downloading images for subject: Mark Turgeon
# This is 1 image for Mark Turgeon
# This is 2 image for Mark Turgeon
# This is 3 image for Mark Turgeon
# This is 4 image for Mark Turgeon
# This is 5 image for Mark Turgeon
# Images for Mark Turgeon downloaded successfully.
# Downloading images for subject: Natalie Cole
# This is 1 image for Natalie Cole
# This is 2 image for Natalie Cole
# This is 3 image for Natalie Cole
# This is 4 image for Natalie Cole
# This is 5 image for Natalie Cole
# Images for Natalie Cole downloaded successfully.
# Downloading images for subject: Jaguar Cars
# This is 1 image for Jaguar Cars
# This is 2 image for Jaguar Cars
# This is 3 image for Jaguar Cars
# This is 4 image for Jaguar Cars
# This is 5 image for Jaguar Cars
# Images for Jaguar Cars downloaded successfully.
# Downloading images for subject: Edward Bellamy
# This is 1 image for Edward Bellamy
# This is 2 image for Edward Bellamy
# This is 3 image for Edward Bellamy
# This is 4 image for Edward Bellamy
# This is 5 image for Edward Bellamy
# Images for Edward Bellamy downloaded successfully.
# Downloading images for subject: José Gálvez FBC
# This is 1 image for José Gálvez FBC
# This is 2 image for José Gálvez FBC
# This is 3 image for José Gálvez FBC
# This is 4 image for José Gálvez FBC
# This is 5 image for José Gálvez FBC
# Images for José Gálvez FBC downloaded successfully.
# Downloading images for subject: Atlanta Braves
# This is 1 image for Atlanta Braves
# This is 2 image for Atlanta Braves
# This is 3 image for Atlanta Braves
# This is 4 image for Atlanta Braves
# This is 5 image for Atlanta Braves
# Images for Atlanta Braves downloaded successfully.
# Downloading images for subject: Minister for Home Affairs
# This is 1 image for Minister for Home Affairs
# This is 2 image for Minister for Home Affairs
# This is 3 image for Minister for Home Affairs
# This is 4 image for Minister for Home Affairs
# This is 5 image for Minister for Home Affairs
# Images for Minister for Home Affairs downloaded successfully.
# Downloading images for subject: Brandon Jennings
# This is 1 image for Brandon Jennings
# This is 2 image for Brandon Jennings
# This is 3 image for Brandon Jennings
# This is 4 image for Brandon Jennings
# This is 5 image for Brandon Jennings
# Images for Brandon Jennings downloaded successfully.
# Downloading images for subject: Da Ali G Show
# This is 1 image for Da Ali G Show
# This is 2 image for Da Ali G Show
# This is 3 image for Da Ali G Show
# This is 4 image for Da Ali G Show
# This is 5 image for Da Ali G Show
# Images for Da Ali G Show downloaded successfully.
# Downloading images for subject: Bert Trautmann
# This is 1 image for Bert Trautmann
# This is 2 image for Bert Trautmann
# This is 3 image for Bert Trautmann
# This is 4 image for Bert Trautmann
# This is 5 image for Bert Trautmann
# Images for Bert Trautmann downloaded successfully.
# Downloading images for subject: Agents of S.H.I.E.L.D.
# This is 1 image for Agents of S.H.I.E.L.D.
# This is 2 image for Agents of S.H.I.E.L.D.
# This is 3 image for Agents of S.H.I.E.L.D.
# This is 4 image for Agents of S.H.I.E.L.D.
# This is 5 image for Agents of S.H.I.E.L.D.
# Images for Agents of S.H.I.E.L.D. downloaded successfully.
# Downloading images for subject: Luke Sutton
# This is 1 image for Luke Sutton
# This is 2 image for Luke Sutton
# This is 3 image for Luke Sutton
# This is 4 image for Luke Sutton
# This is 5 image for Luke Sutton
# Images for Luke Sutton downloaded successfully.
# Downloading images for subject: Ray Bradbury
# This is 1 image for Ray Bradbury
# This is 2 image for Ray Bradbury
# This is 3 image for Ray Bradbury
# This is 4 image for Ray Bradbury
# This is 5 image for Ray Bradbury
# Images for Ray Bradbury downloaded successfully.
# Downloading images for subject: Paul Gascoigne
# This is 1 image for Paul Gascoigne
# This is 2 image for Paul Gascoigne
# This is 3 image for Paul Gascoigne
# This is 4 image for Paul Gascoigne
# This is 5 image for Paul Gascoigne
# Images for Paul Gascoigne downloaded successfully.
# Downloading images for subject: Blumhouse Productions
# This is 1 image for Blumhouse Productions
# This is 2 image for Blumhouse Productions
# This is 3 image for Blumhouse Productions
# This is 4 image for Blumhouse Productions
# This is 5 image for Blumhouse Productions
# Images for Blumhouse Productions downloaded successfully.
# Downloading images for subject: T. E. Lawrence
# This is 1 image for T. E. Lawrence
# This is 2 image for T. E. Lawrence
# This is 3 image for T. E. Lawrence
# This is 4 image for T. E. Lawrence
# This is 5 image for T. E. Lawrence
# Images for T. E. Lawrence downloaded successfully.
# Downloading images for subject: Miguel de Cervantes
# This is 1 image for Miguel de Cervantes
# This is 2 image for Miguel de Cervantes
# This is 3 image for Miguel de Cervantes
# This is 4 image for Miguel de Cervantes
# This is 5 image for Miguel de Cervantes
# Images for Miguel de Cervantes downloaded successfully.
# Downloading images for subject: John Stuart Mill
# This is 1 image for John Stuart Mill
# This is 2 image for John Stuart Mill
# This is 3 image for John Stuart Mill
# This is 4 image for John Stuart Mill
# This is 5 image for John Stuart Mill
# Images for John Stuart Mill downloaded successfully.
# Downloading images for subject: Hope Solo
# This is 1 image for Hope Solo
# This is 2 image for Hope Solo
# This is 3 image for Hope Solo
# This is 4 image for Hope Solo
# This is 5 image for Hope Solo
# Images for Hope Solo downloaded successfully.
# Downloading images for subject: Stephenie Meyer
# This is 1 image for Stephenie Meyer
# This is 2 image for Stephenie Meyer
# This is 3 image for Stephenie Meyer
# This is 4 image for Stephenie Meyer
# This is 5 image for Stephenie Meyer
# Images for Stephenie Meyer downloaded successfully.
# Downloading images for subject: Mark Trumbo
# This is 1 image for Mark Trumbo
# This is 2 image for Mark Trumbo
# This is 3 image for Mark Trumbo
# This is 4 image for Mark Trumbo
# This is 5 image for Mark Trumbo
# Images for Mark Trumbo downloaded successfully.
# Downloading images for subject: New York City
# This is 1 image for New York City
# This is 2 image for New York City
# This is 3 image for New York City
# This is 4 image for New York City
# This is 5 image for New York City
# Images for New York City downloaded successfully.
# Downloading images for subject: President of the Philippines
# This is 1 image for President of the Philippines
# This is 2 image for President of the Philippines
# This is 3 image for President of the Philippines
# This is 4 image for President of the Philippines
# This is 5 image for President of the Philippines
# Images for President of the Philippines downloaded successfully.
# Downloading images for subject: August Derleth
# This is 1 image for August Derleth
# This is 2 image for August Derleth
# This is 3 image for August Derleth
# This is 4 image for August Derleth
# This is 5 image for August Derleth
# Images for August Derleth downloaded successfully.
# All images downloaded successfully.

# %%
# date：2020.5.25
# author:pmy
# aim:爬取google图片
#问题在于，不能保证所爬为所见

from selenium import webdriver
import time
import os
import requests

# 修改keyword便可以修改搜索关键词 建议也修改存储目录
keyword = 'cat'
url = 'https://www.google.com.hk/search?q=' + keyword + '&source=lnms&tbm=isch'


class Crawler_google_images:
    # 初始化
    def __init__(self):
        self.url = url

    # 获得Chrome驱动，并访问url
    def init_browser(self):
        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--disable-infobars")
        browser = webdriver.Chrome(options=chrome_options)
        # 访问url
        browser.get(self.url)
        # 最大化窗口，之后需要爬取窗口中所见的所有图片
        browser.maximize_window()
        return browser

    # 下载图片
    def download_images(self, browser, num=5):
        #存储路径
        picpath = './cat'
        # 路径不存在时创建一个
        if not os.path.exists(picpath): os.makedirs(picpath)

        count = 0  # 图片序号
        pos = 0
        # print(num)

        while (True):
            try:
                # 向下滑动
                js = 'var q=document.documentElement.scrollTop=' + str(pos)
                pos += 500
                browser.execute_script(js)
                time.sleep(1)
                # 找到图片
                # html = browser.page_source#也可以抓取当前页面的html文本，然后用beautifulsoup来抓取
                # 直接通过tag_name来抓取是最简单的，比较方便
                img_elements = browser.find_elements_by_xpath('//a[@class="wXeWr islib nfEiy mM5pbd"]')
                try:
                    for img_element in img_elements:
                        #点开大图页面
                        img_element.click()
                        time.sleep(0.5)
                        try:
                            # 这里balabala里面有好几个，所以要过滤一下
                            # 取名好烦哦···
                            balabalas = browser.find_elements_by_xpath('//img[@class="n3VNCb"]')

                            if (balabalas):
                                for balabala in balabalas:
                                    src = balabala.get_attribute('src')
                                    #过滤掉缩略图和无关干扰信息
                                    if src.startswith('http') and not src.startswith(
                                            'https://encrypted-tbn0.gstatic.com'):
                                        print('Found' + str(count) + 'st image url')
                                        # img_url_dic.append(src)
                                        self.save_img(count, src, picpath)
                                        count += 1
                                        #爬取到指定数量图片后退出
                                        if (count >= num):
                                            return "stop"
                        except:
                            print('获取图片失败')

                    #回退
                    browser.back()
                    time.sleep(0.3)
                except:
                    print('获取页面失败')
            except:
                print("划不动了")

    def save_img(self, count, img_src, picpath):
        filename = picpath + '/' + str(count) + '.jpg'
        r = requests.get(img_src)
        with open(filename, 'wb') as f:
            f.write(r.content)
        f.close()

    def run(self):
        self.__init__()
        browser = self.init_browser()
        self.download_images(browser, 100)  # 可以修改爬取的图片数
        browser.close()
        print("############爬取完成")


if __name__ == '__main__':
    craw = Crawler_google_images()
    craw.run()
